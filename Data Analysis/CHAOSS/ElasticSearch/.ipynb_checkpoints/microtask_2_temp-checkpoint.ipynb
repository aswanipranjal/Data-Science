# %% [markdown]
# # Microtask 2
# ---
# Produce a chart showing the distribution of time-to-close (using the corresponding field in the GrimoireLab enriched index for GitHub issues) for issues already closed, and opened during the last six months.

# %%
from datetime import datetime
from elasticsearch import Elasticsearch
from elasticsearch_dsl import Search

import subprocess
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Assuming we have a running instance of Elasticsearch locally at http://localhost:9200

# %%
# elasticsearch instance
es = Elasticsearch('http://localhost:9200', verify_certs=False)

# %% [markdown]
# The [grimoirelab-perceval](https://github.com/chaoss/grimoirelab-perceval) repository will be used

# %%
org = 'chaoss'
repo = 'grimoirelab-perceval'
token = ''

# %% [markdown]
# Run the `p2o.py` subprocess to generate the indices.

# %%
subprocess.run(['p2o.py', '--enrich', '--index', 'perceval_github_raw', '--index-enrich', 'perceval_github', '-e', 'http://localhost:9200', '--no_inc', '--debug', 'github', org, repo, '-t', token, '--sleep-for-rate'])
# Out:
# CompletedProcess(args=['p2o.py', '--enrich', '--index', 'perceval_github_raw', '--index-enrich', 'perceval_github', '-e', 'http://localhost:9200', '--no_inc', '--debug', 'github', 'chaoss', 'grimoirelab-perceval', '-t', '1be89fc7151192be77782ef93778861242a48925', '--sleep-for-rate'], returncode=0)

# %% [markdown]
# Frame a query for the required information using the `elasticsearch_dsl` module.

# %%
s = Search(using=es, index='perceval_github')
# filter by issues
s = s.filter('terms', item_type=['issue'])
# filter issues created in the last six months
s = s.filter('range', created_at={'gte' : 'now-6M'})
# get required fields
s = s.source(['time_to_close_days', 'time_open_days', 'item_type', 'created_at', 'closed_at', 'author_name', 'id_in_repo'])
# sort by creation date
s = s.sort({'created_at': {'order': 'asc'}})
# limit the number of results
s = s[0:1000]

# %%
# execute the query
result = s.execute()

# %%
# convert to dictionary and keep only relevant information
result = result.to_dict()['hits']['hits']
result
# Out:
# [{'_id': '6eae638c3522c4c9ee2478686b7bad08876b2476',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Santiago Dueñas',
#    'closed_at': '2017-09-15T08:45:58Z',
#    'created_at': '2017-09-13T09:55:38Z',
#    'id_in_repo': '155',
#    'item_type': 'issue',
#    'time_open_days': 1.95,
#    'time_to_close_days': 1.95},
#   '_type': 'items',
#   'sort': [1505296538000]},
#  {'_id': '3d3e02bda92ce73b96056b27052aea783f2d6e43',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Santiago Dueñas',
#    'closed_at': '2017-10-07T14:41:19Z',
#    'created_at': '2017-09-13T10:01:38Z',
#    'id_in_repo': '156',
#    'item_type': 'issue',
#    'time_open_days': 24.19,
#    'time_to_close_days': 24.19},
#   '_type': 'items',
#   'sort': [1505296898000]},
#  {'_id': '39b0d3f62a402c3a11997f199af27ddd0e0fab05',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Jesus M. Gonzalez-Barahona',
#    'closed_at': None,
#    'created_at': '2017-09-19T21:52:22Z',
#    'id_in_repo': '160',
#    'item_type': 'issue',
#    'time_open_days': 170.99,
#    'time_to_close_days': None},
#   '_type': 'items',
#   'sort': [1505857942000]},
#  {'_id': '196dd75b3e376162faa62f78a8595c8bcd6bb0b7',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Alvaro del Castillo',
#    'closed_at': '2017-09-27T11:24:36Z',
#    'created_at': '2017-09-22T04:45:33Z',
#    'id_in_repo': '162',
#    'item_type': 'issue',
#    'time_open_days': 5.28,
#    'time_to_close_days': 5.28},
#   '_type': 'items',
#   'sort': [1506055533000]},
#  {'_id': 'b7124dbb4740d1bf240012ea75d893d703078b6e',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Alvaro del Castillo',
#    'closed_at': '2017-11-07T12:07:50Z',
#    'created_at': '2017-09-25T21:02:07Z',
#    'id_in_repo': '165',
#    'item_type': 'issue',
#    'time_open_days': 42.63,
#    'time_to_close_days': 42.63},
#   '_type': 'items',
#   'sort': [1506373327000]},
#  {'_id': '4cc0f1cac90a9888321c15bb9e565e46a2719ba8',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Alvaro del Castillo',
#    'closed_at': '2017-09-29T17:21:43Z',
#    'created_at': '2017-09-26T15:04:45Z',
#    'id_in_repo': '167',
#    'item_type': 'issue',
#    'time_open_days': 3.1,
#    'time_to_close_days': 3.1},
#   '_type': 'items',
#   'sort': [1506438285000]},
#  {'_id': '4cda02dee9ef63804afa560e9bde018b6481cc32',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Santiago Dueñas',
#    'closed_at': None,
#    'created_at': '2017-09-27T11:44:00Z',
#    'id_in_repo': '168',
#    'item_type': 'issue',
#    'time_open_days': 163.41,
#    'time_to_close_days': None},
#   '_type': 'items',
#   'sort': [1506512640000]},
#  {'_id': 'a55a697d550868a8e60256b3622421c3bd5bccef',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Alvaro del Castillo',
#    'closed_at': '2017-10-10T14:27:30Z',
#    'created_at': '2017-10-09T16:20:16Z',
#    'id_in_repo': '174',
#    'item_type': 'issue',
#    'time_open_days': 0.92,
#    'time_to_close_days': 0.92},
#   '_type': 'items',
#   'sort': [1507566016000]},
#  {'_id': '88599f95ec0678b670fb4a3ec8e3974f4e4d7771',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Alvaro del Castillo',
#    'closed_at': '2017-10-24T12:30:36Z',
#    'created_at': '2017-10-09T18:22:00Z',
#    'id_in_repo': '175',
#    'item_type': 'issue',
#    'time_open_days': 14.76,
#    'time_to_close_days': 14.76},
#   '_type': 'items',
#   'sort': [1507573320000]},
#  {'_id': 'fed94b8fe5399a895bd82991bf23dc446374e898',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Alberto Martín',
#    'closed_at': '2017-10-16T19:13:11Z',
#    'created_at': '2017-10-11T12:24:04Z',
#    'id_in_repo': '178',
#    'item_type': 'issue',
#    'time_open_days': 5.28,
#    'time_to_close_days': 5.28},
#   '_type': 'items',
#   'sort': [1507724644000]},
#  {'_id': '37a48f4d0180ef680ce60e9d3d2097cf786d2165',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Alvaro del Castillo',
#    'closed_at': '2017-10-30T10:15:59Z',
#    'created_at': '2017-10-16T10:48:08Z',
#    'id_in_repo': '180',
#    'item_type': 'issue',
#    'time_open_days': 13.98,
#    'time_to_close_days': 13.98},
#   '_type': 'items',
#   'sort': [1508150888000]},
#  {'_id': 'fcfc139d2e84bfe684685b47520782936db7ecfd',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Quan Zhou',
#    'closed_at': '2017-10-25T17:41:25Z',
#    'created_at': '2017-10-16T13:33:20Z',
#    'id_in_repo': '181',
#    'item_type': 'issue',
#    'time_open_days': 9.17,
#    'time_to_close_days': 9.17},
#   '_type': 'items',
#   'sort': [1508160800000]},
#  {'_id': 'bf61180b0a851f911ae96792c3392738c243b874',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Alvaro del Castillo',
#    'closed_at': '2017-11-08T18:46:02Z',
#    'created_at': '2017-10-16T17:34:48Z',
#    'id_in_repo': '183',
#    'item_type': 'issue',
#    'time_open_days': 23.05,
#    'time_to_close_days': 23.05},
#   '_type': 'items',
#   'sort': [1508175288000]},
#  {'_id': '8e6d7c4c56aa1eaf33fed3084fa8c14a7032eefe',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': None,
#    'closed_at': '2017-10-25T08:09:05Z',
#    'created_at': '2017-10-24T19:27:29Z',
#    'id_in_repo': '187',
#    'item_type': 'issue',
#    'time_open_days': 0.53,
#    'time_to_close_days': 0.53},
#   '_type': 'items',
#   'sort': [1508873249000]},
#  {'_id': 'b6dd49dd9a309bdbb28a56a626bc739b745eb7a1',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Manrique Lopez',
#    'closed_at': '2017-11-15T14:00:31Z',
#    'created_at': '2017-10-30T23:09:47Z',
#    'id_in_repo': '191',
#    'item_type': 'issue',
#    'time_open_days': 15.62,
#    'time_to_close_days': 15.62},
#   '_type': 'items',
#   'sort': [1509404987000]},
#  {'_id': 'a2b85586e14b451e81dd8502e93da7df6ef44527',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Alberto Martín',
#    'closed_at': '2017-11-08T11:38:22Z',
#    'created_at': '2017-11-07T09:45:32Z',
#    'id_in_repo': '197',
#    'item_type': 'issue',
#    'time_open_days': 1.08,
#    'time_to_close_days': 1.08},
#   '_type': 'items',
#   'sort': [1510047932000]},
#  {'_id': '16f00203411c3abd527646f6ed19fad4d0377102',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Jesus M. Gonzalez-Barahona',
#    'closed_at': '2017-11-09T12:03:24Z',
#    'created_at': '2017-11-07T16:39:34Z',
#    'id_in_repo': '201',
#    'item_type': 'issue',
#    'time_open_days': 1.81,
#    'time_to_close_days': 1.81},
#   '_type': 'items',
#   'sort': [1510072774000]},
#  {'_id': '143eb5e67f5ebb58cc79ce965f048629368b7d84',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Quan Zhou',
#    'closed_at': '2017-11-14T12:11:32Z',
#    'created_at': '2017-11-08T10:04:09Z',
#    'id_in_repo': '202',
#    'item_type': 'issue',
#    'time_open_days': 6.09,
#    'time_to_close_days': 6.09},
#   '_type': 'items',
#   'sort': [1510135449000]},
#  {'_id': 'b55894866af347a00abfcad846819ac1cd0bb456',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Alberto Martín',
#    'closed_at': '2017-11-17T13:32:17Z',
#    'created_at': '2017-11-08T10:33:36Z',
#    'id_in_repo': '203',
#    'item_type': 'issue',
#    'time_open_days': 9.12,
#    'time_to_close_days': 9.12},
#   '_type': 'items',
#   'sort': [1510137216000]},
#  {'_id': 'c09b06e1449de759d7f0d636ad348f363bf56292',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Quan Zhou',
#    'closed_at': '2017-11-08T12:01:53Z',
#    'created_at': '2017-11-08T11:54:07Z',
#    'id_in_repo': '204',
#    'item_type': 'issue',
#    'time_open_days': 0.01,
#    'time_to_close_days': 0.01},
#   '_type': 'items',
#   'sort': [1510142047000]},
#  {'_id': '2e987186eb607186e0ec77dccfe30cdd6a4d8533',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Alvaro del Castillo',
#    'closed_at': '2018-02-05T09:52:30Z',
#    'created_at': '2017-11-15T22:00:07Z',
#    'id_in_repo': '209',
#    'item_type': 'issue',
#    'time_open_days': 81.49,
#    'time_to_close_days': 81.49},
#   '_type': 'items',
#   'sort': [1510783207000]},
#  {'_id': 'c6b0e12cde356979c75280881543e90154fa5209',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Santiago Dueñas',
#    'closed_at': '2017-11-22T13:05:37Z',
#    'created_at': '2017-11-22T11:02:39Z',
#    'id_in_repo': '210',
#    'item_type': 'issue',
#    'time_open_days': 0.09,
#    'time_to_close_days': 0.09},
#   '_type': 'items',
#   'sort': [1511348559000]},
#  {'_id': '4b3e9b4f99ed12a6d8afb83c79ca3bcd5c451ea3',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Alberto Martín',
#    'closed_at': '2017-11-28T17:18:41Z',
#    'created_at': '2017-11-28T10:47:58Z',
#    'id_in_repo': '216',
#    'item_type': 'issue',
#    'time_open_days': 0.27,
#    'time_to_close_days': 0.27},
#   '_type': 'items',
#   'sort': [1511866078000]},
#  {'_id': '2efa2af824ff33fe6973b1fc6c6d0b7a547438b5',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Alberto Martín',
#    'closed_at': None,
#    'created_at': '2017-11-28T10:48:43Z',
#    'id_in_repo': '217',
#    'item_type': 'issue',
#    'time_open_days': 101.45,
#    'time_to_close_days': None},
#   '_type': 'items',
#   'sort': [1511866123000]},
#  {'_id': '339450af264ef9ec55625c26377ee56007ca1111',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': None,
#    'closed_at': '2017-11-30T09:34:39Z',
#    'created_at': '2017-11-29T16:59:29Z',
#    'id_in_repo': '221',
#    'item_type': 'issue',
#    'time_open_days': 0.69,
#    'time_to_close_days': 0.69},
#   '_type': 'items',
#   'sort': [1511974769000]},
#  {'_id': 'f9cd314dc2838ae5faa8c6625779b47316099e80',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Luis Cañas-Díaz',
#    'closed_at': None,
#    'created_at': '2017-11-30T17:40:49Z',
#    'id_in_repo': '229',
#    'item_type': 'issue',
#    'time_open_days': 99.16,
#    'time_to_close_days': None},
#   '_type': 'items',
#   'sort': [1512063649000]},
#  {'_id': 'b737e0e8b0513af51bbef5794b69cd589edb9d31',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Samuel Ytterbrink',
#    'closed_at': None,
#    'created_at': '2017-12-01T09:29:35Z',
#    'id_in_repo': '234',
#    'item_type': 'issue',
#    'time_open_days': 98.5,
#    'time_to_close_days': None},
#   '_type': 'items',
#   'sort': [1512120575000]},
#  {'_id': '9489f3b09bcaa1db15b8e27c52dba6793dd3a8a8',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Alberto Martín',
#    'closed_at': '2018-01-02T15:14:59Z',
#    'created_at': '2017-12-01T12:46:47Z',
#    'id_in_repo': '242',
#    'item_type': 'issue',
#    'time_open_days': 32.1,
#    'time_to_close_days': 32.1},
#   '_type': 'items',
#   'sort': [1512132407000]},
#  {'_id': 'c7aa9de4dbeffc021c0daba262e1a9c28fd162d8',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Alberto Martín',
#    'closed_at': '2017-12-13T16:06:25Z',
#    'created_at': '2017-12-05T08:26:47Z',
#    'id_in_repo': '243',
#    'item_type': 'issue',
#    'time_open_days': 8.32,
#    'time_to_close_days': 8.32},
#   '_type': 'items',
#   'sort': [1512462407000]},
#  {'_id': '69585f35d27e69394b81668e48d10c053d53df1e',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Alberto Martín',
#    'closed_at': '2017-12-11T19:22:20Z',
#    'created_at': '2017-12-05T09:38:37Z',
#    'id_in_repo': '244',
#    'item_type': 'issue',
#    'time_open_days': 6.41,
#    'time_to_close_days': 6.41},
#   '_type': 'items',
#   'sort': [1512466717000]},
#  {'_id': 'b6d54d544bc8e1fc82a5c09d04d25f2562abad78',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Alberto Martín',
#    'closed_at': '2017-12-11T12:59:45Z',
#    'created_at': '2017-12-05T10:28:42Z',
#    'id_in_repo': '247',
#    'item_type': 'issue',
#    'time_open_days': 6.1,
#    'time_to_close_days': 6.1},
#   '_type': 'items',
#   'sort': [1512469722000]},
#  {'_id': 'fa0f8ad93251091fbe4c413659cbea22a663526d',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Manrique Lopez',
#    'closed_at': '2017-12-18T10:47:29Z',
#    'created_at': '2017-12-15T08:55:13Z',
#    'id_in_repo': '254',
#    'item_type': 'issue',
#    'time_open_days': 3.08,
#    'time_to_close_days': 3.08},
#   '_type': 'items',
#   'sort': [1513328113000]},
#  {'_id': '98c80245cdd2d2c4cd05d5aa132655ebe8b81052',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Santiago Dueñas',
#    'closed_at': '2017-12-18T16:22:17Z',
#    'created_at': '2017-12-18T11:39:22Z',
#    'id_in_repo': '257',
#    'item_type': 'issue',
#    'time_open_days': 0.2,
#    'time_to_close_days': 0.2},
#   '_type': 'items',
#   'sort': [1513597162000]},
#  {'_id': '22bba0ac12f35a47cde686093f331d83573cbb6d',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Alberto Martín',
#    'closed_at': '2017-12-26T15:45:10Z',
#    'created_at': '2017-12-21T21:34:00Z',
#    'id_in_repo': '260',
#    'item_type': 'issue',
#    'time_open_days': 4.76,
#    'time_to_close_days': 4.76},
#   '_type': 'items',
#   'sort': [1513892040000]},
#  {'_id': '7a660884f71e56eea25fef16e3c86d5ffa9623e1',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Alberto Martín',
#    'closed_at': '2017-12-27T17:34:50Z',
#    'created_at': '2017-12-22T15:27:08Z',
#    'id_in_repo': '261',
#    'item_type': 'issue',
#    'time_open_days': 5.09,
#    'time_to_close_days': 5.09},
#   '_type': 'items',
#   'sort': [1513956428000]},
#  {'_id': '70e366a3acacace6fe30c40397ecd839f9965218',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Santiago Dueñas',
#    'closed_at': '2018-01-02T13:56:41Z',
#    'created_at': '2017-12-26T11:41:57Z',
#    'id_in_repo': '262',
#    'item_type': 'issue',
#    'time_open_days': 7.09,
#    'time_to_close_days': 7.09},
#   '_type': 'items',
#   'sort': [1514288517000]},
#  {'_id': 'd21ba59d868f297248a4d01c52a1ed53c13fb5be',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Santiago Dueñas',
#    'closed_at': '2017-12-27T17:04:56Z',
#    'created_at': '2017-12-26T19:13:19Z',
#    'id_in_repo': '264',
#    'item_type': 'issue',
#    'time_open_days': 0.91,
#    'time_to_close_days': 0.91},
#   '_type': 'items',
#   'sort': [1514315599000]},
#  {'_id': '726c9302070524d9ad7da3f3c161d4f414dc0f16',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Alvaro del Castillo',
#    'closed_at': '2017-12-27T10:39:03Z',
#    'created_at': '2017-12-27T10:32:00Z',
#    'id_in_repo': '265',
#    'item_type': 'issue',
#    'time_open_days': 0.0,
#    'time_to_close_days': 0.0},
#   '_type': 'items',
#   'sort': [1514370720000]},
#  {'_id': 'af151d8958985d922d18b9c777d0219aecdcb604',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': None,
#    'closed_at': '2018-01-15T10:55:18Z',
#    'created_at': '2018-01-06T20:11:19Z',
#    'id_in_repo': '270',
#    'item_type': 'issue',
#    'time_open_days': 8.61,
#    'time_to_close_days': 8.61},
#   '_type': 'items',
#   'sort': [1515269479000]},
#  {'_id': 'e94d170fbba5dd41319d74ffb91abf486d8464cd',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Alvaro del Castillo',
#    'closed_at': '2018-02-12T10:50:22Z',
#    'created_at': '2018-01-17T06:35:40Z',
#    'id_in_repo': '277',
#    'item_type': 'issue',
#    'time_open_days': 26.18,
#    'time_to_close_days': 26.18},
#   '_type': 'items',
#   'sort': [1516170940000]},
#  {'_id': '7e859791672a03cb911e6dc1a0d011465d05aaa7',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Santiago Dueñas',
#    'closed_at': '2018-01-29T16:15:00Z',
#    'created_at': '2018-01-26T12:51:35Z',
#    'id_in_repo': '309',
#    'item_type': 'issue',
#    'time_open_days': 3.14,
#    'time_to_close_days': 3.14},
#   '_type': 'items',
#   'sort': [1516971095000]},
#  {'_id': '4c473782fb0ac3be34f17e65d688fe500430146a',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Manrique Lopez',
#    'closed_at': None,
#    'created_at': '2018-02-09T15:33:40Z',
#    'id_in_repo': '318',
#    'item_type': 'issue',
#    'time_open_days': 28.25,
#    'time_to_close_days': None},
#   '_type': 'items',
#   'sort': [1518190420000]},
#  {'_id': 'a910a4e60fb632492c59414d71d3350cf0257c51',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Armijn Hemel',
#    'closed_at': None,
#    'created_at': '2018-02-09T16:29:36Z',
#    'id_in_repo': '319',
#    'item_type': 'issue',
#    'time_open_days': 28.21,
#    'time_to_close_days': None},
#   '_type': 'items',
#   'sort': [1518193776000]},
#  {'_id': '1b1de72573fef54ef727c5e030ee070f6730da7c',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Sachin S. Kamath',
#    'closed_at': None,
#    'created_at': '2018-02-14T08:57:59Z',
#    'id_in_repo': '324',
#    'item_type': 'issue',
#    'time_open_days': 23.52,
#    'time_to_close_days': None},
#   '_type': 'items',
#   'sort': [1518598679000]},
#  {'_id': '3e4bf59257286a9a728c9529ccfcd1606d541938',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Manrique Lopez',
#    'closed_at': None,
#    'created_at': '2018-02-15T08:37:18Z',
#    'id_in_repo': '325',
#    'item_type': 'issue',
#    'time_open_days': 22.54,
#    'time_to_close_days': None},
#   '_type': 'items',
#   'sort': [1518683838000]},
#  {'_id': 'c4b2ba3fabe703f0cf87fde50ad095feddece37e',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Sachin S. Kamath',
#    'closed_at': '2018-02-19T10:02:53Z',
#    'created_at': '2018-02-17T08:56:30Z',
#    'id_in_repo': '326',
#    'item_type': 'issue',
#    'time_open_days': 2.05,
#    'time_to_close_days': 2.05},
#   '_type': 'items',
#   'sort': [1518857790000]},
#  {'_id': '6c2433258bc99d2692556c98486555337549a299',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Taewan Kim',
#    'closed_at': '2018-02-19T23:48:50Z',
#    'created_at': '2018-02-19T11:03:51Z',
#    'id_in_repo': '327',
#    'item_type': 'issue',
#    'time_open_days': 0.53,
#    'time_to_close_days': 0.53},
#   '_type': 'items',
#   'sort': [1519038231000]},
#  {'_id': '18f886632fa03f011b2136346f979269813f3aad',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': None,
#    'closed_at': None,
#    'created_at': '2018-02-21T06:13:04Z',
#    'id_in_repo': '331',
#    'item_type': 'issue',
#    'time_open_days': 16.64,
#    'time_to_close_days': None},
#   '_type': 'items',
#   'sort': [1519193584000]},
#  {'_id': '2f1bc969d6906895a52e4a1c928e41d778755b1b',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'valerio',
#    'closed_at': '2018-03-05T10:37:17Z',
#    'created_at': '2018-03-01T09:45:12Z',
#    'id_in_repo': '335',
#    'item_type': 'issue',
#    'time_open_days': 4.04,
#    'time_to_close_days': 4.04},
#   '_type': 'items',
#   'sort': [1519897512000]},
#  {'_id': '3e575d0230e8d7f45f4db3ab40c8ce49af0172b7',
#   '_index': 'perceval_github',
#   '_score': None,
#   '_source': {'author_name': 'Jesus M. Gonzalez-Barahona',
#    'closed_at': '2018-03-06T08:58:35Z',
#    'created_at': '2018-03-02T18:22:45Z',
#    'id_in_repo': '337',
#    'item_type': 'issue',
#    'time_open_days': 3.61,
#    'time_to_close_days': 3.61},
#   '_type': 'items',
#   'sort': [1520014965000]}]

# %%
# issues
issues = [issue['_source'] for issue in result]
issues = pd.DataFrame(issues)
issues.head()
# Out:
#                   author_name             closed_at            created_at  \
# 0             Santiago Dueñas  2017-09-15T08:45:58Z  2017-09-13T09:55:38Z
# 1             Santiago Dueñas  2017-10-07T14:41:19Z  2017-09-13T10:01:38Z
# 2  Jesus M. Gonzalez-Barahona                  None  2017-09-19T21:52:22Z
# 3         Alvaro del Castillo  2017-09-27T11:24:36Z  2017-09-22T04:45:33Z
# 4         Alvaro del Castillo  2017-11-07T12:07:50Z  2017-09-25T21:02:07Z
#
#   id_in_repo item_type  time_open_days  time_to_close_days
# 0        155     issue            1.95                1.95
# 1        156     issue           24.19               24.19
# 2        160     issue          170.99                 NaN
# 3        162     issue            5.28                5.28
# 4        165     issue           42.63               42.63

# %%
issues
# Out:
#                    author_name             closed_at            created_at  \
# 0              Santiago Dueñas  2017-09-15T08:45:58Z  2017-09-13T09:55:38Z
# 1              Santiago Dueñas  2017-10-07T14:41:19Z  2017-09-13T10:01:38Z
# 2   Jesus M. Gonzalez-Barahona                  None  2017-09-19T21:52:22Z
# 3          Alvaro del Castillo  2017-09-27T11:24:36Z  2017-09-22T04:45:33Z
# 4          Alvaro del Castillo  2017-11-07T12:07:50Z  2017-09-25T21:02:07Z
# 5          Alvaro del Castillo  2017-09-29T17:21:43Z  2017-09-26T15:04:45Z
# 6              Santiago Dueñas                  None  2017-09-27T11:44:00Z
# 7          Alvaro del Castillo  2017-10-10T14:27:30Z  2017-10-09T16:20:16Z
# 8          Alvaro del Castillo  2017-10-24T12:30:36Z  2017-10-09T18:22:00Z
# 9               Alberto Martín  2017-10-16T19:13:11Z  2017-10-11T12:24:04Z
# 10         Alvaro del Castillo  2017-10-30T10:15:59Z  2017-10-16T10:48:08Z
# 11                   Quan Zhou  2017-10-25T17:41:25Z  2017-10-16T13:33:20Z
# 12         Alvaro del Castillo  2017-11-08T18:46:02Z  2017-10-16T17:34:48Z
# 13                        None  2017-10-25T08:09:05Z  2017-10-24T19:27:29Z
# 14              Manrique Lopez  2017-11-15T14:00:31Z  2017-10-30T23:09:47Z
# 15              Alberto Martín  2017-11-08T11:38:22Z  2017-11-07T09:45:32Z
# 16  Jesus M. Gonzalez-Barahona  2017-11-09T12:03:24Z  2017-11-07T16:39:34Z
# 17                   Quan Zhou  2017-11-14T12:11:32Z  2017-11-08T10:04:09Z
# 18              Alberto Martín  2017-11-17T13:32:17Z  2017-11-08T10:33:36Z
# 19                   Quan Zhou  2017-11-08T12:01:53Z  2017-11-08T11:54:07Z
# 20         Alvaro del Castillo  2018-02-05T09:52:30Z  2017-11-15T22:00:07Z
# 21             Santiago Dueñas  2017-11-22T13:05:37Z  2017-11-22T11:02:39Z
# 22              Alberto Martín  2017-11-28T17:18:41Z  2017-11-28T10:47:58Z
# 23              Alberto Martín                  None  2017-11-28T10:48:43Z
# 24                        None  2017-11-30T09:34:39Z  2017-11-29T16:59:29Z
# 25             Luis Cañas-Díaz                  None  2017-11-30T17:40:49Z
# 26           Samuel Ytterbrink                  None  2017-12-01T09:29:35Z
# 27              Alberto Martín  2018-01-02T15:14:59Z  2017-12-01T12:46:47Z
# 28              Alberto Martín  2017-12-13T16:06:25Z  2017-12-05T08:26:47Z
# 29              Alberto Martín  2017-12-11T19:22:20Z  2017-12-05T09:38:37Z
# 30              Alberto Martín  2017-12-11T12:59:45Z  2017-12-05T10:28:42Z
# 31              Manrique Lopez  2017-12-18T10:47:29Z  2017-12-15T08:55:13Z
# 32             Santiago Dueñas  2017-12-18T16:22:17Z  2017-12-18T11:39:22Z
# 33              Alberto Martín  2017-12-26T15:45:10Z  2017-12-21T21:34:00Z
# 34              Alberto Martín  2017-12-27T17:34:50Z  2017-12-22T15:27:08Z
# 35             Santiago Dueñas  2018-01-02T13:56:41Z  2017-12-26T11:41:57Z
# 36             Santiago Dueñas  2017-12-27T17:04:56Z  2017-12-26T19:13:19Z
# 37         Alvaro del Castillo  2017-12-27T10:39:03Z  2017-12-27T10:32:00Z
# 38                        None  2018-01-15T10:55:18Z  2018-01-06T20:11:19Z
# 39         Alvaro del Castillo  2018-02-12T10:50:22Z  2018-01-17T06:35:40Z
# 40             Santiago Dueñas  2018-01-29T16:15:00Z  2018-01-26T12:51:35Z
# 41              Manrique Lopez                  None  2018-02-09T15:33:40Z
# 42                Armijn Hemel                  None  2018-02-09T16:29:36Z
# 43            Sachin S. Kamath                  None  2018-02-14T08:57:59Z
# 44              Manrique Lopez                  None  2018-02-15T08:37:18Z
# 45            Sachin S. Kamath  2018-02-19T10:02:53Z  2018-02-17T08:56:30Z
# 46                  Taewan Kim  2018-02-19T23:48:50Z  2018-02-19T11:03:51Z
# 47                        None                  None  2018-02-21T06:13:04Z
# 48                     valerio  2018-03-05T10:37:17Z  2018-03-01T09:45:12Z
# 49  Jesus M. Gonzalez-Barahona  2018-03-06T08:58:35Z  2018-03-02T18:22:45Z
#
#    id_in_repo item_type  time_open_days  time_to_close_days
# 0         155     issue            1.95                1.95
# 1         156     issue           24.19               24.19
# 2         160     issue          170.99                 NaN
# 3         162     issue            5.28                5.28
# 4         165     issue           42.63               42.63
# 5         167     issue            3.10                3.10
# 6         168     issue          163.41                 NaN
# 7         174     issue            0.92                0.92
# 8         175     issue           14.76               14.76
# 9         178     issue            5.28                5.28
# 10        180     issue           13.98               13.98
# 11        181     issue            9.17                9.17
# 12        183     issue           23.05               23.05
# 13        187     issue            0.53                0.53
# 14        191     issue           15.62               15.62
# 15        197     issue            1.08                1.08
# 16        201     issue            1.81                1.81
# 17        202     issue            6.09                6.09
# 18        203     issue            9.12                9.12
# 19        204     issue            0.01                0.01
# 20        209     issue           81.49               81.49
# 21        210     issue            0.09                0.09
# 22        216     issue            0.27                0.27
# 23        217     issue          101.45                 NaN
# 24        221     issue            0.69                0.69
# 25        229     issue           99.16                 NaN
# 26        234     issue           98.50                 NaN
# 27        242     issue           32.10               32.10
# 28        243     issue            8.32                8.32
# 29        244     issue            6.41                6.41
# 30        247     issue            6.10                6.10
# 31        254     issue            3.08                3.08
# 32        257     issue            0.20                0.20
# 33        260     issue            4.76                4.76
# 34        261     issue            5.09                5.09
# 35        262     issue            7.09                7.09
# 36        264     issue            0.91                0.91
# 37        265     issue            0.00                0.00
# 38        270     issue            8.61                8.61
# 39        277     issue           26.18               26.18
# 40        309     issue            3.14                3.14
# 41        318     issue           28.25                 NaN
# 42        319     issue           28.21                 NaN
# 43        324     issue           23.52                 NaN
# 44        325     issue           22.54                 NaN
# 45        326     issue            2.05                2.05
# 46        327     issue            0.53                0.53
# 47        331     issue           16.64                 NaN
# 48        335     issue            4.04                4.04
# 49        337     issue            3.61                3.61

# %%
ax = issues.plot(x=issues['id_in_repo'], kind='bar', figsize=(20, 10))
ax.set_title('Issues for the last 6 months')
ax.set_xlabel('Issue number')
ax.set_ylabel('Days open')
plt.show()
