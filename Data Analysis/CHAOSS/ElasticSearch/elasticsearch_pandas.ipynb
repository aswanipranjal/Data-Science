# %%
from datetime import datetime

from elasticsearch import Elasticsearch
from elasticsearch_dsl import Search
import pandas as pd

# %%
es = Elasticsearch('http://localhost:9200', verify_certs=False)

# %%
s = Search(using=es, index='git')
s.aggs.bucket('by_authors', 'terms', field='author_name', size=10000).metric('first_commit', 'min', field='author_date')
s = s.sort('author_date')

# %%
result = s.execute()

# %%
result
# Out:
# <Response: [<Hit(git/items/29ddd736146e278feb5d84e9dcc1fd310ff50007): {'metadata__updated_on': '2015-08-18T16:08:27+00:00', 'metad...}>, <Hit(git/items/ea70266506018422ccc250c7e3a011723bf93070): {'metadata__updated_on': '2015-08-18T16:11:40+00:00', 'metad...}>, <Hit(git/items/a3bba1de63d524ec1ffaae3ba8fdd208855fc462): {'metadata__updated_on': '2015-08-18T16:54:45+00:00', 'metad...}>, <Hit(git/items/1b49d6e6b0ac2a0cbeaaf3bf2892db4c4888b9a4): {'metadata__updated_on': '2015-08-20T17:01:05+00:00', 'metad...}>, <Hit(git/items/8cfbd71b24f0d9b1929d708ab531ed64baf622aa): {'metadata__updated_on': '2015-08-21T09:17:01+00:00', 'metad...}>, <Hit(git/items/9f9cf6231eab830ae9c6153492a54ea42c9211c3): {'metadata__updated_on': '2015-08-21T09:18:21+00:00', 'metad...}>, <Hit(git/items/e813e2cf40b5e7eb772e637b06c02c08263780b0): {'metadata__updated_on': '2015-08-21T09:47:00+00:00', 'metad...}>, <Hit(git/items/87cd0f77fe98ed9bb0f7080f7807fa0032fbc589): {'metadata__updated_on': '2015-08-21T10:26:51+00:00', 'metad...}>, <Hit(git/items/a92c40925731d8951418e27630f0f5a361d8e33f): {'metadata__updated_on': '2015-09-30T16:15:16+00:00', 'metad...}>, <Hit(git/items/21a3aa5befc41fff5f7d2b7131e58ac0e2a58b33): {'metadata__updated_on': '2015-09-30T16:16:08+00:00', 'metad...}>]>

# %%
buckets_result = result['aggregations']['by_authors']['buckets']

# %%
buckets_result
# Out:
# [{'key': 'Alvaro del Castillo', 'doc_count': 1624, 'first_commit': {'value': 1443636916000.0, 'value_as_string': '2015-09-30T18:15:16.000Z'}}, {'key': 'Santiago Dueñas', 'doc_count': 713, 'first_commit': {'value': 1439921307000.0, 'value_as_string': '2015-08-18T18:08:27.000Z'}}, {'key': 'Valerio Cosentino', 'doc_count': 214, 'first_commit': {'value': 1505391244000.0, 'value_as_string': '2017-09-14T12:14:04.000Z'}}, {'key': 'Alberto Martín', 'doc_count': 57, 'first_commit': {'value': 1455033405000.0, 'value_as_string': '2016-02-09T15:56:45.000Z'}}, {'key': 'Jesus M. Gonzalez-Barahona', 'doc_count': 54, 'first_commit': {'value': 1451589385000.0, 'value_as_string': '2015-12-31T19:16:25.000Z'}}, {'key': 'Luis Cañas Díaz', 'doc_count': 46, 'first_commit': {'value': 1457631487000.0, 'value_as_string': '2016-03-10T17:38:07.000Z'}}, {'key': 'Luis Cañas-Díaz', 'doc_count': 34, 'first_commit': {'value': 1457631390000.0, 'value_as_string': '2016-03-10T17:36:30.000Z'}}, {'key': 'quan', 'doc_count': 22, 'first_commit': {'value': 1459512989000.0, 'value_as_string': '2016-04-01T12:16:29.000Z'}}, {'key': 'dpose', 'doc_count': 19, 'first_commit': {'value': 1467892420000.0, 'value_as_string': '2016-07-07T11:53:40.000Z'}}, {'key': 'alpgarcia', 'doc_count': 8, 'first_commit': {'value': 1479401984000.0, 'value_as_string': '2016-11-17T16:59:44.000Z'}}, {'key': 'Luis Canas-Diaz', 'doc_count': 6, 'first_commit': {'value': 1467801493000.0, 'value_as_string': '2016-07-06T10:38:13.000Z'}}, {'key': 'valerio cosentino', 'doc_count': 6, 'first_commit': {'value': 1504795590000.0, 'value_as_string': '2017-09-07T14:46:30.000Z'}}, {'key': 'David Pose Fernández', 'doc_count': 4, 'first_commit': {'value': 1478187638000.0, 'value_as_string': '2016-11-03T15:40:38.000Z'}}, {'key': 'Daniel Izquierdo', 'doc_count': 3, 'first_commit': {'value': 1499280338000.0, 'value_as_string': '2017-07-05T18:45:38.000Z'}}, {'key': 'Miguel Ángel Fernández', 'doc_count': 3, 'first_commit': {'value': 1518440171000.0, 'value_as_string': '2018-02-12T12:56:11.000Z'}}, {'key': 'Quan Zhou', 'doc_count': 3, 'first_commit': {'value': 1467646657000.0, 'value_as_string': '2016-07-04T15:37:37.000Z'}}, {'key': 'camillem', 'doc_count': 2, 'first_commit': {'value': 1459163284000.0, 'value_as_string': '2016-03-28T11:08:04.000Z'}}, {'key': 'valerio', 'doc_count': 2, 'first_commit': {'value': 1507652849000.0, 'value_as_string': '2017-10-10T16:27:29.000Z'}}, {'key': 'Alberto Pérez García-Plaza', 'doc_count': 1, 'first_commit': {'value': 1511528747000.0, 'value_as_string': '2017-11-24T13:05:47.000Z'}}, {'key': 'Ali Ghassabian', 'doc_count': 1, 'first_commit': {'value': 1501848183000.0, 'value_as_string': '2017-08-04T12:03:03.000Z'}}, {'key': 'David Esler', 'doc_count': 1, 'first_commit': {'value': 1508280396000.0, 'value_as_string': '2017-10-17T22:46:36.000Z'}}, {'key': 'Israel Herraiz', 'doc_count': 1, 'first_commit': {'value': 1515512457000.0, 'value_as_string': '2018-01-09T15:40:57.000Z'}}, {'key': 'J. Manrique Lopez de la Fuente', 'doc_count': 1, 'first_commit': {'value': 1457165042000.0, 'value_as_string': '2016-03-05T08:04:02.000Z'}}, {'key': 'Stephan Barth', 'doc_count': 1, 'first_commit': {'value': 1483980776000.0, 'value_as_string': '2017-01-09T16:52:56.000Z'}}, {'key': 'david', 'doc_count': 1, 'first_commit': {'value': 1512672893000.0, 'value_as_string': '2017-12-07T18:54:53.000Z'}}]

# %%
buckets = []

# %%
for bucket in buckets_result:
    first_commit = bucket['first_commit']['value']/1000
    buckets.append({'first_commit':datetime.utcfromtimestamp(first_commit), 'author':bucket['key']})

# %%
buckets
# Out:
# [{'author': 'Alvaro del Castillo',
#   'first_commit': datetime.datetime(2015, 9, 30, 18, 15, 16)},
#  {'author': 'Santiago Dueñas',
#   'first_commit': datetime.datetime(2015, 8, 18, 18, 8, 27)},
#  {'author': 'Valerio Cosentino',
#   'first_commit': datetime.datetime(2017, 9, 14, 12, 14, 4)},
#  {'author': 'Alberto Martín',
#   'first_commit': datetime.datetime(2016, 2, 9, 15, 56, 45)},
#  {'author': 'Jesus M. Gonzalez-Barahona',
#   'first_commit': datetime.datetime(2015, 12, 31, 19, 16, 25)},
#  {'author': 'Luis Cañas Díaz',
#   'first_commit': datetime.datetime(2016, 3, 10, 17, 38, 7)},
#  {'author': 'Luis Cañas-Díaz',
#   'first_commit': datetime.datetime(2016, 3, 10, 17, 36, 30)},
#  {'author': 'quan', 'first_commit': datetime.datetime(2016, 4, 1, 12, 16, 29)},
#  {'author': 'dpose',
#   'first_commit': datetime.datetime(2016, 7, 7, 11, 53, 40)},
#  {'author': 'alpgarcia',
#   'first_commit': datetime.datetime(2016, 11, 17, 16, 59, 44)},
#  {'author': 'Luis Canas-Diaz',
#   'first_commit': datetime.datetime(2016, 7, 6, 10, 38, 13)},
#  {'author': 'valerio cosentino',
#   'first_commit': datetime.datetime(2017, 9, 7, 14, 46, 30)},
#  {'author': 'David Pose Fernández',
#   'first_commit': datetime.datetime(2016, 11, 3, 15, 40, 38)},
#  {'author': 'Daniel Izquierdo',
#   'first_commit': datetime.datetime(2017, 7, 5, 18, 45, 38)},
#  {'author': 'Miguel Ángel Fernández',
#   'first_commit': datetime.datetime(2018, 2, 12, 12, 56, 11)},
#  {'author': 'Quan Zhou',
#   'first_commit': datetime.datetime(2016, 7, 4, 15, 37, 37)},
#  {'author': 'camillem',
#   'first_commit': datetime.datetime(2016, 3, 28, 11, 8, 4)},
#  {'author': 'valerio',
#   'first_commit': datetime.datetime(2017, 10, 10, 16, 27, 29)},
#  {'author': 'Alberto Pérez García-Plaza',
#   'first_commit': datetime.datetime(2017, 11, 24, 13, 5, 47)},
#  {'author': 'Ali Ghassabian',
#   'first_commit': datetime.datetime(2017, 8, 4, 12, 3, 3)},
#  {'author': 'David Esler',
#   'first_commit': datetime.datetime(2017, 10, 17, 22, 46, 36)},
#  {'author': 'Israel Herraiz',
#   'first_commit': datetime.datetime(2018, 1, 9, 15, 40, 57)},
#  {'author': 'J. Manrique Lopez de la Fuente',
#   'first_commit': datetime.datetime(2016, 3, 5, 8, 4, 2)},
#  {'author': 'Stephan Barth',
#   'first_commit': datetime.datetime(2017, 1, 9, 16, 52, 56)},
#  {'author': 'david',
#   'first_commit': datetime.datetime(2017, 12, 7, 18, 54, 53)}]

# %%
print(result.to_dict())
# Out:
# {'took': 169, 'timed_out': False, '_shards': {'total': 5, 'successful': 5, 'skipped': 0, 'failed': 0}, 'hits': {'total': 2827, 'max_score': None, 'hits': [{'_index': 'git', '_type': 'items', '_id': '29ddd736146e278feb5d84e9dcc1fd310ff50007', '_score': None, '_source': {'metadata__updated_on': '2015-08-18T16:08:27+00:00', 'metadata__timestamp': '2018-03-02T14:42:44.190662+00:00', 'offset': None, 'origin': 'https://github.com/grimoirelab/perceval.git', 'tag': 'https://github.com/grimoirelab/perceval.git', 'uuid': '29ddd736146e278feb5d84e9dcc1fd310ff50007', 'message': 'Initial import', 'Author': 'Santiago Dueñas <sduenas@bitergia.com>', 'hash': 'dc78c254e464ff334892e0448a23e4cfbfc637a3', 'message_analyzed': 'Initial import', 'Committer': 'Santiago Dueñas <sduenas@bitergia.com>', 'hash_short': 'dc78c2', 'author_date': '2015-08-18T18:08:27', 'commit_date': '2015-08-18T18:08:27', 'utc_author': '2015-08-18T16:08:27', 'utc_commit': '2015-08-18T16:08:27', 'tz': 2, 'repo_name': 'https://github.com/grimoirelab/perceval.git', 'files': 3, 'lines_added': 685, 'lines_removed': 0, 'lines_changed': 685, 'author_name': 'Santiago Dueñas', 'author_domain': 'bitergia.com', 'committer_name': 'Santiago Dueñas', 'committer_domain': 'bitergia.com', 'title': 'Initial import', 'github_repo': 'grimoirelab/perceval', 'url_id': 'grimoirelab/perceval/commit/dc78c254e464ff334892e0448a23e4cfbfc637a3', 'grimoire_creation_date': '2015-08-18T18:08:27+02:00', 'is_git_commit': 1, 'metadata__gelk_version': '0.30.23', 'metadata__gelk_backend_name': 'GitEnrich', 'metadata__enriched_on': '2018-03-02T20:12:49.432461'}, 'sort': [1439921307000]}, {'_index': 'git', '_type': 'items', '_id': 'ea70266506018422ccc250c7e3a011723bf93070', '_score': None, '_source': {'metadata__updated_on': '2015-08-18T16:11:40+00:00', 'metadata__timestamp': '2018-03-02T14:42:44.191988+00:00', 'offset': None, 'origin': 'https://github.com/grimoirelab/perceval.git', 'tag': 'https://github.com/grimoirelab/perceval.git', 'uuid': 'ea70266506018422ccc250c7e3a011723bf93070', 'message': '[tests] Set up unit tests framework', 'Author': 'Santiago Dueñas <sduenas@bitergia.com>', 'hash': '57bc204822832a6c23ac7883e5392f4da6f4ca37', 'message_analyzed': '[tests] Set up unit tests framework', 'Committer': 'Santiago Dueñas <sduenas@bitergia.com>', 'hash_short': '57bc20', 'author_date': '2015-08-18T18:11:40', 'commit_date': '2015-08-18T18:11:40', 'utc_author': '2015-08-18T16:11:40', 'utc_commit': '2015-08-18T16:11:40', 'tz': 2, 'repo_name': 'https://github.com/grimoirelab/perceval.git', 'files': 2, 'lines_added': 31, 'lines_removed': 0, 'lines_changed': 31, 'author_name': 'Santiago Dueñas', 'author_domain': 'bitergia.com', 'committer_name': 'Santiago Dueñas', 'committer_domain': 'bitergia.com', 'title': '[tests] Set up unit tests framework', 'github_repo': 'grimoirelab/perceval', 'url_id': 'grimoirelab/perceval/commit/57bc204822832a6c23ac7883e5392f4da6f4ca37', 'grimoire_creation_date': '2015-08-18T18:11:40+02:00', 'is_git_commit': 1, 'metadata__gelk_version': '0.30.23', 'metadata__gelk_backend_name': 'GitEnrich', 'metadata__enriched_on': '2018-03-02T20:12:49.434347'}, 'sort': [1439921500000]}, {'_index': 'git', '_type': 'items', '_id': 'a3bba1de63d524ec1ffaae3ba8fdd208855fc462', '_score': None, '_source': {'metadata__updated_on': '2015-08-18T16:54:45+00:00', 'metadata__timestamp': '2018-03-02T14:42:44.192780+00:00', 'offset': None, 'origin': 'https://github.com/grimoirelab/perceval.git', 'tag': 'https://github.com/grimoirelab/perceval.git', 'uuid': 'a3bba1de63d524ec1ffaae3ba8fdd208855fc462', 'message': '[perceval] Add perceval script', 'Author': 'Santiago Dueñas <sduenas@bitergia.com>', 'hash': '2355d18310d8e15c8e5d44f688d757df33b0e4be', 'message_analyzed': '[perceval] Add perceval script', 'Committer': 'Santiago Dueñas <sduenas@bitergia.com>', 'hash_short': '2355d1', 'author_date': '2015-08-18T18:54:45', 'commit_date': '2015-08-18T18:54:45', 'utc_author': '2015-08-18T16:54:45', 'utc_commit': '2015-08-18T16:54:4 ...

# %%
from pprint import pprint
pprint(result.to_dict())
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 5, 'total': 5},
#  'aggregations': {'by_authors': {'buckets': [{'doc_count': 1624,
#                                               'first_commit': {'value': 1443636916000.0,
#                                                                'value_as_string': '2015-09-30T18:15:16.000Z'},
#                                               'key': 'Alvaro del Castillo'},
#                                              {'doc_count': 713,
#                                               'first_commit': {'value': 1439921307000.0,
#                                                                'value_as_string': '2015-08-18T18:08:27.000Z'},
#                                               'key': 'Santiago Dueñas'},
#                                              {'doc_count': 214,
#                                               'first_commit': {'value': 1505391244000.0,
#                                                                'value_as_string': '2017-09-14T12:14:04.000Z'},
#                                               'key': 'Valerio Cosentino'},
#                                              {'doc_count': 57,
#                                               'first_commit': {'value': 1455033405000.0,
#                                                                'value_as_string': '2016-02-09T15:56:45.000Z'},
#                                               'key': 'Alberto Martín'},
#                                              {'doc_count': 54,
#                                               'first_commit': {'value': 1451589385000.0,
#                                                                'value_as_string': '2015-12-31T19:16:25.000Z'},
#                                               'key': 'Jesus M. '
#                                                      'Gonzalez-Barahona'},
#                                              {'doc_count': 46,
#                                               'first_commit': {'value': 1457631487000.0,
#                                                                'value_as_string': '2016-03-10T17:38:07.000Z'},
#                                               'key': 'Luis Cañas Díaz'},
#                                              {'doc_count': 34,
#                                               'first_commit': {'value': 1457631390000.0,
#                                                                'value_as_string': '2016-03-10T17:36:30.000Z'},
#                                               'key': 'Luis Cañas-Díaz'},
#                                              {'doc_count': 22,
#                                               'first_commit': {'value': 1459512989000.0,
#                                                                'value_as_string': '2016-04-01T12:16:29.000Z'},
#                                               'key': 'quan'},
#                                              {'doc_count': 19,
#                                               'first_commit': {'value': 1467892420000.0,
#                                                                'value_as_string': '2016-07-07T11:53:40.000Z'},
#                                               'key': 'dpose'},
#                                              {'doc_count': 8,
#                                               'first_commit': {'value': 1479401984000.0,
#                                                                'value_as_string': '2016-11-17T16:59:44.000Z'},
#                                               'key': 'alpgarcia'},
#                                              {'doc_count': 6,
#                                               'first_commit': {'value': 1467801493000.0,
#                                                                'value_as_string': '2016-07-06T10:38:13.000Z'},
#                                               'key': 'Luis Canas-Diaz'},
#                                              {'doc_count': 6,
#                                               'first_commit': {'value': 1504795590000.0,
#                                                                'value_as_string': '2017-09-07T14:46:30.000Z'},
#                                               'key': 'valerio cosentino'},
#                                              {'doc_count': 4,
#                                               'first_commit': {'value': 1478187638000.0,
#                                                                'value_as_string': '2016-11-03T15:40:38.000Z'},
#                                               'key': 'David Pose Fernández'},
#                                              {'doc_count': 3,
#                                               'first_commit': {'value': 1499280338000.0,
#                                                                'value_as_string': '2017-07-05T18:45:38.000Z'},
#                                               'key': 'Daniel Izquierdo'},
#                                              {'doc_count': 3,
#                                               'first_commit': {'value': 1518440171000.0,
#                                                                'value_as_string': '2018-02-12T12:56:11.000Z'},
#                                               'key': 'Miguel Ángel Fernández'},
#                                              {'doc_count': 3,
#                                               'first_commit': {'value': 1467646657000.0,
#                                                                'value_as_string': '2016-07-04T15:37:37.000Z'},
#                                               'key': 'Quan Zhou'},
#                                              {'doc_count': 2,
#                                               'first_commit': {'value': 1459163284000.0,
#                                                                'value_as_string': '2016-03-28T11:08:04.000Z'},
#                                               'key': 'camillem'},
#                                              {'doc_count': 2,
#                                               'first_commit': {'value': 1507652849000.0,
#                                                                'value_as_string': '2017-10-10T16:27:29.000Z'},
#                                               'key': 'valerio'},
#                                              {'doc_count': 1,
#                                               'first_commit': {'value': 1511528747000.0,
#                                                                'value_as_string': '2017-11-24T13:05:47.000Z'},
#                                               'key': 'Alberto Pérez '
#                                                      'García-Plaza'},
#                                              {'doc_count': 1,
#                                               'first_commit': {'value': 1501848183000.0,
#                                                                'value_as_string': '2017-08-04T12:03:03.000Z'},
#                                               'key': 'Ali Ghassabian'},
#                                              {'doc_count': 1,
#                                               'first_commit': {'value': 1508280396000.0,
#                                                                'value_as_string': '2017-10-17T22:46:36.000Z'},
#                                               'key': 'David Esler'},
#                                              {'doc_count': 1,
#                                               'first_commit': {'value': 1515512457000.0,
#                                                                'value_as_string': '2018-01-09T15:40:57.000Z'},
#                                               'key': 'Israel Herraiz'},
#                                              {'doc_count': 1,
#                                               'first_commit': {'value': 1457165042000.0,
#                                                                'value_as_string': '2016-03-05T08:04:02.000Z'},
#                                               'key': 'J. Manrique Lopez de la '
#                                                      'Fuente'},
#                                              {'doc_count': 1,
#                                               'first_commit': {'value': 1483980776000.0,
#                                                                'value_as_string': '2017-01-09T16:52:56.000Z'},
#                                               'key': 'Stephan Barth'},
#                                              {'doc_count': 1,
#                                               'first_commit': {'value': 1512672893000.0,
#                                                                'value_as_string': '2017-12-07T18:54:53.000Z'},
#                                               'key': 'david'}],
#                                  'doc_count_error_upper_bound': 0,
#                                  'sum_other_doc_count': 0}},
#  'hits': {'hits': [{'_id': '29ddd736146e278feb5d84e9dcc1fd310ff50007',
#                     '_index': 'git',
#                     '_score': None,
#                     '_source': {'Author': 'Santiago Dueñas '
#                                           '<sduenas@bitergia.com>',
#                                 'Committer': 'Santiago Dueñas '
#                                              '<sduenas@bitergia.com>',
#                                 'author_date': '2015-08-18T18:08:27',
#                                 'author_domain': 'bitergia.com',
#                                 'author_name': 'Santiago Dueñas',
#                                 'commit_date': '2015-08-18T18:08:27',
#                                 'committer_domain': 'bitergia.com',
#                                 'committer_name': 'Santiago Dueñas',
#                                 'files': 3,
#                                 'github_repo': 'grimoirelab/perceval',
#                                 'grimoire_creation_date': '2015-08-18T18:08:27+02:00',
#                                 'hash': 'dc78c254e464ff334892e0448a23e4cfbfc637a3',
#                                 'hash_short': 'dc78c2',
#                                 'is_git_commit': 1,
#                                 'lines_added': 685,
#                                 'lines_changed': 685,
#                                 'lines_removed': 0,
#                                 'message': 'Initial import',
#                                 'message_analyzed': 'Initial import',
#                                 'metadata__enriched_on': '2018-03-02T20:12:49.432461',
#                                 'metadata__gelk_backend_name': 'GitEnrich',
#                                 'metadata__gelk_version': '0.30.23',
#                                 'metadata__timestamp': '2018-03-02T14:42:44.190662+00:00',
#                                 'metadata__updated_on': '2015-08-18T16:08:27+00:00',
#                                 'offset': None,
#                                 'origin': 'https://github.com/grimoirelab/perceval.git',
#                                 'repo_name': 'https://github.com/grimoirelab/perceval.git',
#                                 'tag': 'https://github.com/grimoirelab/perceval.git',
#                                 'title': 'Initial import',
#                                 'tz': 2,
#                                 'url_id': 'grimoirelab/perceval/commit/dc78c254e464ff334892e0448a23e4cfbfc637a3',
#                                 'utc_author': '2015-08-18T16:08:27',
#                                 'utc_commit': '2015-08-18T16:08:27',
#                                 'uuid': '29ddd736146e278feb5d84e9dcc1fd310ff50007'},
#                     '_type': 'items',
#                     'sort': [1439921307000]},
#                    {'_id': 'ea70266506018422ccc250c7e3a011723bf93070',
#                     '_index': 'git',
#                     '_score': None,
#                     '_source': {'Author': 'Santiago Dueñas '
#                                           '<sduenas@bitergia.com>',
#                                 'Committer': 'Santiago Dueñas '
#                                              '<sduenas@bitergia.com>',
#                                 'author_date': '2015-08-18T18:11:40',
#                                 'author_domain': 'bitergia.com',
#                                 'author_name': 'Santiago Dueñas',
#                                 'commit_date': '2015-08-18T18:11:40',
#                                 'committer_domain': 'bitergia.com',
#                                 'committer_name': 'Santiago Dueñas',
#                                 'files': 2,
#                                 'github_repo': 'grimoirelab/perceval',
#                                 'grimoire_creation_date': '2015-08-18T18:11:40+02:00',
#                                 'hash': '57bc204822832a6c23ac7883e5392f4da6f4ca37',
#                                 'hash_short': '57bc20',
#                                 'is_git_commit': 1,
#                                 'lines_added': 31,
#                                 'lines_changed': 31,
#                                 'lines_removed': 0,
#                                 'message': '[tests] Set up unit tests '
#                                            'framework',
#                                 'message_analyzed': '[tests] Set up unit tests '
#                                                     'framework',
#                                 'metadata__enriched_on': '2018-03-02T20:12:49.434347',
#                                 'metadata__gelk_backend_name': 'GitEnrich',
#                                 'metadata__gelk_version': '0.30.23',
#                                 'metadata__timestamp': '2018-03-02T14:42:44.191988+00:00',
#                                 'metadata__updated_on': '2015-08-18T16:11:40+00:00',
#                                 'offset': None,
#                                 'origin': 'https://github.com/grimoirelab/perceval.git',
#                                 'repo_name': 'https://github.com/grimoirelab/perceval.git',
#                                 'tag': 'https://github.com/grimoirelab/perceval.git',
#                                 'title': '[tests] Set up unit tests framework',
#                                 'tz': 2,
#                                 'url_id': 'grimoirelab/perceval/commit/57bc204822832a6c23ac7883e5392f4da6f4ca37',
#                                 'utc_author': '2015-08-18T16:11:40',
#                                 'utc_commit': '2015-08-18T16:11:40',
#                                 'uuid': 'ea70266506018422ccc250c7e3a011723bf93070'},
#                     '_type': 'items',
#                     'sort': [1439921500000]},
#                    {'_id': 'a3bba1de63d524ec1ffaae3ba8fdd208855fc462',
#                     '_index': 'git',
#                     '_score': None,
#                     '_source': {'Author': 'Santiago Dueñas '
#                                           '<sduenas@bitergia.com>',
#                                 'Committer': 'Santiago Dueñas '
#                                              '<sduenas@bitergia.com>',
#                                 'author_date': '2015-08-18T18:54:45',
#                                 'author_domain': 'bitergia.com',
#                                 'author_name': 'Santiago Dueñas',
#                                 'commit_date': '2015-08-18T18:54:45',
#                                 'committer_domain': 'bitergia.com',
#                                 'committer_name': 'Santiago Dueñas',
#                                 'files': 1,
#                                 'github_repo': 'grimoirelab/perceval',
#                                 'grimoire_creation_date': '2015-08-18T18:54:45+02:00',
#                                 'hash': '2355d18310d8e15c8e5d44f688d757df33b0e4be',
#                                 'hash_short': '2355d1',
#                                 'is_git_commit': 1,
#                                 'lines_added': 74,
#                                 'lines_changed': 74,
#                                 'lines_removed': 0,
#                                 'message': '[perceval] Add perceval script',
#                                 'message_analyzed': '[perceval] Add perceval '
#                                                     'script',
#                                 'metadata__enriched_on': '2018-03-02T20:12:49.436066',
#                                 'metadata__gelk_backend_name': 'GitEnrich',
#                                 'metadata__gelk_version': '0.30.23',
#                                 'metadata__timestamp': '2018-03-02T14:42:44.192780+00:00',
#                                 'metadata__updated_on': '2015-08-18T16:54:45+00:00',
#                                 'offset': None,
#                                 'origin': 'https://github.com/grimoirelab/perceval.git',
#                                 'repo_name': 'https://github.com/grimoirelab/perceval.git',
#                                 'tag': 'https://github.com/grimoirelab/perceval.git',
#                                 'title': '[perceval] Add perceval script',
#                                 'tz': 2,
#                                 'url_id': 'grimoirelab/perceval/commit/2355d18310d8e15c8e5d44f688d757df33b0e4be',
#                                 'utc_author': '2015-08-18T16:54:45',
#                                 'utc_commit': '2015-08-18T16:54:45',
#                                 'uuid': 'a3bba1de63d524ec1ffaae3ba8fdd208855fc462'},
#                     '_type': 'items',
#                     'sort': [1439924085000]},
#                    {'_id': '1b49d6e6b0ac2a0cbeaaf3bf2892db4c4888b9a4',
#                     '_index': 'git',
#                     '_score': None,
#                     '_source': {'Author': 'Santiago Dueñas '
#                                           '<sduenas@bitergia.com>',
#                                 'Committer': 'Santiago Dueñas '
#                                              '<sduenas@bitergia.com>',
#                                 'author_date': '2015-08-20T19:01:05',
#                                 'author_domain': 'bitergia.com',
#                                 'author_name': 'Santiago Dueñas',
#                                 'commit_date': '2015-08-20T19:01:05',
#                                 'committer_domain': 'bitergia.com',
#                                 'committer_name': 'Santiago Dueñas',
#                                 'files': 1,
#                                 'github_repo': 'grimoirelab/perceval',
#                                 'grimoire_creation_date': '2015-08-20T19:01:05+02:00',
#                                 'hash': '589bc515db1632959f6edcb0c4bc2fe43ee51b74',
#                                 'hash_short': '589bc5',
#                                 'is_git_commit': 1,
#                                 'lines_added': 47,
#                                 'lines_changed': 48,
#                                 'lines_removed': 1,
#                                 'message': '[perceval] Support configuration '
#                                            'file',
#                                 'message_analyzed': '[perceval] Support '
#                                                     'configuration file',
#                                 'metadata__enriched_on': '2018-03-02T20:12:49.437831',
#                                 'metadata__gelk_backend_name': 'GitEnrich',
#                                 'metadata__gelk_version': '0.30.23',
#                                 'metadata__timestamp': '2018-03-02T14:42:44.193525+00:00',
#                                 'metadata__updated_on': '2015-08-20T17:01:05+00:00',
#                                 'offset': None,
#                                 'origin': 'https://github.com/grimoirelab/perceval.git',
#                                 'repo_name': 'https://github.com/grimoirelab/perceval.git',
#                                 'tag': 'https://github.com/grimoirelab/perceval.git',
#                                 'title': '[perceval] Support configuration '
#                                          'file',
#                                 'tz': 2,
#                                 'url_id': 'grimoirelab/perceval/commit/589bc515db1632959f6edcb0c4bc2fe43ee51b74',
#                                 'utc_author': '2015-08-20T17:01:05',
#                                 'utc_commit': '2015-08-20T17:01:05',
#                                 'uuid': '1b49d6e6b0ac2a0cbeaaf3bf2892db4c4888b9a4'},
#                     '_type': 'items',
#                     'sort': [1440097265000]},
#                    {'_id': '8cfbd71b24f0d9b1929d708ab531ed64baf622aa',
#                     '_index': 'git',
#                     '_score': None,
#                     '_source': {'Author': 'Santiago Dueñas '
#                                           '<sduenas@bitergia.com>',
#                                 'Committer': 'Santiago Dueñas '
#                                              '<sduenas@bitergia.com>',
#                                 'author_date': '2015-08-21T11:17:01',
#                                 'author_domain': 'bitergia.com',
#                                 'author_name': 'Santiago Dueñas',
#                                 'commit_date': '2015-08-21T11:17:01',
#                                 'committer_domain': 'bitergia.com',
#                                 'committer_name': 'Santiago Dueñas',
#                                 'files': 1,
#                                 'github_repo': 'grimoirelab/perceval',
#                                 'grimoire_creation_date': '2015-08-21T11:17:01+02:00',
#                                 'hash': '35bfeb3c4037a31f4f6a885243f213a104772a04',
#                                 'hash_short': '35bfeb',
#                                 'is_git_commit': 1,
#                                 'lines_added': 32,
#                                 'lines_changed': 32,
#                                 'lines_removed': 0,
#                                 'message': 'Add setup.py',
#                                 'message_analyzed': 'Add setup.py',
#                                 'metadata__enriched_on': '2018-03-02T20:12:49.439916',
#                                 'metadata__gelk_backend_name': 'GitEnrich',
#                                 'metadata__gelk_version': '0.30.23',
#                                 'metadata__timestamp': '2018-03-02T14:42:44.194463+00:00',
#                                 'metadata__updated_on': '2015-08-21T09:17:01+00:00',
#                                 'offset': None,
#                                 'origin': 'https://github.com/grimoirelab/perceval.git',
#                                 'repo_name': 'https://github.com/grimoirelab/perceval.git',
#                                 'tag': 'https://github.com/grimoirelab/perceval.git',
#                                 'title': 'Add setup.py',
#                                 'tz': 2,
#                                 'url_id': 'grimoirelab/perceval/commit/35bfeb3c4037a31f4f6a885243f213a104772a04',
#                                 'utc_author': '2015-08-21T09:17:01',
#                                 'utc_commit': '2015-08-21T09:17:01',
#                                 'uuid': '8cfbd71b24f0d9b1929d708ab531ed64baf622aa'},
#                     '_type': 'items',
#                     'sort': [1440155821000]},
#                    {'_id': '9f9cf6231eab830ae9c6153492a54ea42c9211c3',
#                     '_index': 'git',
#                     '_score': None,
#                     '_source': {'Author': 'Santiago Dueñas '
#                                           '<sduenas@bitergia.com>',
#                                 'Committer': 'Santiago Dueñas '
#                                              '<sduenas@bitergia.com>',
#                                 'author_date': '2015-08-21T11:18:21',
#                                 'author_domain': 'bitergia.com',
#                                 'author_name': 'Santiago Dueñas',
#                                 'commit_date': '2015-08-21T11:18:21',
#                                 'committer_domain': 'bitergia.com',
#                                 'committer_name': 'Santiago Dueñas',
#                                 'files': 4,
#                                 'github_repo': 'grimoirelab/perceval',
#                                 'grimoire_creation_date': '2015-08-21T11:18:21+02:00',
#                                 'hash': 'f6238e73f5bba86efd5e5fdd55a84b2b4f7348ec',
#                                 'hash_short': 'f6238e',
#                                 'is_git_commit': 1,
#                                 'lines_added': 92,
#                                 'lines_changed': 95,
#                                 'lines_removed': 3,
#                                 'message': '[backend] Add '
#                                            'get_argument_parser() class method',
#                                 'message_analyzed': '[backend] Add '
#                                                     'get_argument_parser() '
#                                                     'class method',
#                                 'metadata__enriched_on': '2018-03-02T20:12:49.440878',
#                                 'metadata__gelk_backend_name': 'GitEnrich',
#                                 'metadata__gelk_version': '0.30.23',
#                                 'metadata__timestamp': '2018-03-02T14:42:44.195549+00:00',
#                                 'metadata__updated_on': '2015-08-21T09:18:21+00:00',
#                                 'offset': None,
#                                 'origin': 'https://github.com/grimoirelab/perceval.git',
#                                 'repo_name': 'https://github.com/grimoirelab/perceval.git',
#                                 'tag': 'https://github.com/grimoirelab/perceval.git',
#                                 'title': '[backend] Add get_argument_parser() '
#                                          'class method',
#                                 'tz': 2,
#                                 'url_id': 'grimoirelab/perceval/commit/f6238e73f5bba86efd5e5fdd55a84b2b4f7348ec',
#                                 'utc_author': '2015-08-21T09:18:21',
#                                 'utc_commit': '2015-08-21T09:18:21',
#                                 'uuid': '9f9cf6231eab830ae9c6153492a54ea42c9211c3'},
#                     '_type': 'items',
#                     'sort': [1440155901000]},
#                    {'_id': 'e813e2cf40b5e7eb772e637b06c02c08263780b0',
#                     '_index': 'git',
#                     '_score': None,
#                     '_source': {'Author': 'Santiago Dueñas '
#                                           '<sduenas@bitergia.com>',
#                                 'Committer': 'Santiago Dueñas '
#                                              '<sduenas@bitergia.com>',
#                                 'author_date': '2015-08-21T11:47:00',
#                                 'author_domain': 'bitergia.com',
#                                 'author_name': 'Santiago Dueñas',
#                                 'commit_date': '2015-08-21T11:47:00',
#                                 'committer_domain': 'bitergia.com',
#                                 'committer_name': 'Santiago Dueñas',
#                                 'files': 1,
#                                 'github_repo': 'grimoirelab/perceval',
#                                 'grimoire_creation_date': '2015-08-21T11:47:00+02:00',
#                                 'hash': '2ff7af1b6e5b202697518c307f4d4d68a5cb1b7b',
#                                 'hash_short': '2ff7af',
#                                 'is_git_commit': 1,
#                                 'lines_added': 1,
#                                 'lines_changed': 2,
#                                 'lines_removed': 1,
#                                 'message': 'Update gitignore blacklist',
#                                 'message_analyzed': 'Update gitignore '
#                                                     'blacklist',
#                                 'metadata__enriched_on': '2018-03-02T20:12:49.441743',
#                                 'metadata__gelk_backend_name': 'GitEnrich',
#                                 'metadata__gelk_version': '0.30.23',
#                                 'metadata__timestamp': '2018-03-02T14:42:44.196459+00:00',
#                                 'metadata__updated_on': '2015-08-21T09:47:00+00:00',
#                                 'offset': None,
#                                 'origin': 'https://github.com/grimoirelab/perceval.git',
#                                 'repo_name': 'https://github.com/grimoirelab/perceval.git',
#                                 'tag': 'https://github.com/grimoirelab/perceval.git',
#                                 'title': 'Update gitignore blacklist',
#                                 'tz': 2,
#                                 'url_id': 'grimoirelab/perceval/commit/2ff7af1b6e5b202697518c307f4d4d68a5cb1b7b',
#                                 'utc_author': '2015-08-21T09:47:00',
#                                 'utc_commit': '2015-08-21T09:47:00',
#                                 'uuid': 'e813e2cf40b5e7eb772e637b06c02c08263780b0'},
#                     '_type': 'items',
#                     'sort': [1440157620000]},
#                    {'_id': '87cd0f77fe98ed9bb0f7080f7807fa0032fbc589',
#                     '_index': 'git',
#                     '_score': None,
#                     '_source': {'Author': 'Santiago Dueñas '
#                                           '<sduenas@bitergia.com>',
#                                 'Committer': 'Santiago Dueñas '
#                                              '<sduenas@bitergia.com>',
#                                 'author_date': '2015-08-21T12:26:51',
#                                 'author_domain': 'bitergia.com',
#                                 'author_name': 'Santiago Dueñas',
#                                 'commit_date': '2015-08-21T12:26:51',
#                                 'committer_domain': 'bitergia.com',
#                                 'committer_name': 'Santiago Dueñas',
#                                 'files': 2,
#                                 'github_repo': 'grimoirelab/perceval',
#                                 'grimoire_creation_date': '2015-08-21T12:26:51+02:00',
#                                 'hash': '4e34582f9cfd8ec64841d5db5333c598a4082632',
#                                 'hash_short': '4e3458',
#                                 'is_git_commit': 1,
#                                 'lines_added': 108,
#                                 'lines_changed': 108,
#                                 'lines_removed': 0,
#                                 'message': '[errors] Add Perceval base error '
#                                            'class',
#                                 'message_analyzed': '[errors] Add Perceval '
#                                                     'base error class',
#                                 'metadata__enriched_on': '2018-03-02T20:12:49.442580',
#                                 'metadata__gelk_backend_name': 'GitEnrich',
#                                 'metadata__gelk_version': '0.30.23',
#                                 'metadata__timestamp': '2018-03-02T14:42:44.197567+00:00',
#                                 'metadata__updated_on': '2015-08-21T10:26:51+00:00',
#                                 'offset': None,
#                                 'origin': 'https://github.com/grimoirelab/perceval.git',
#                                 'repo_name': 'https://github.com/grimoirelab/perceval.git',
#                                 'tag': 'https://github.com/grimoirelab/perceval.git',
#                                 'title': '[errors] Add Perceval base error '
#                                          'class',
#                                 'tz': 2,
#                                 'url_id': 'grimoirelab/perceval/commit/4e34582f9cfd8ec64841d5db5333c598a4082632',
#                                 'utc_author': '2015-08-21T10:26:51',
#                                 'utc_commit': '2015-08-21T10:26:51',
#                                 'uuid': '87cd0f77fe98ed9bb0f7080f7807fa0032fbc589'},
#                     '_type': 'items',
#                     'sort': [1440160011000]},
#                    {'_id': 'a92c40925731d8951418e27630f0f5a361d8e33f',
#                     '_index': 'git',
#                     '_score': None,
#                     '_source': {'Author': 'Alvaro del Castillo '
#                                           '<acs@bitergia.com>',
#                                 'Committer': 'Alvaro del Castillo '
#                                              '<acs@bitergia.com>',
#                                 'author_date': '2015-09-30T18:15:16',
#                                 'author_domain': 'bitergia.com',
#                                 'author_name': 'Alvaro del Castillo',
#                                 'commit_date': '2015-09-30T18:15:16',
#                                 'committer_domain': 'bitergia.com',
#                                 'committer_name': 'Alvaro del Castillo',
#                                 'files': 1,
#                                 'github_repo': 'grimoirelab/GrimoireELK',
#                                 'grimoire_creation_date': '2015-09-30T18:15:16+02:00',
#                                 'hash': '0c94d393af840a896af9d500e8f26ee6ac4f4d26',
#                                 'hash_short': '0c94d3',
#                                 'is_git_commit': 1,
#                                 'lines_added': 1,
#                                 'lines_changed': 1,
#                                 'lines_removed': 0,
#                                 'message': 'Initial commit',
#                                 'message_analyzed': 'Initial commit',
#                                 'metadata__enriched_on': '2018-03-02T20:13:38.536577',
#                                 'metadata__gelk_backend_name': 'GitEnrich',
#                                 'metadata__gelk_version': '0.30.23',
#                                 'metadata__timestamp': '2018-03-02T14:43:33.946950+00:00',
#                                 'metadata__updated_on': '2015-09-30T16:15:16+00:00',
#                                 'offset': None,
#                                 'origin': 'https://github.com/grimoirelab/GrimoireELK.git',
#                                 'repo_name': 'https://github.com/grimoirelab/GrimoireELK.git',
#                                 'tag': 'https://github.com/grimoirelab/GrimoireELK.git',
#                                 'title': 'Initial commit',
#                                 'tz': 2,
#                                 'url_id': 'grimoirelab/GrimoireELK/commit/0c94d393af840a896af9d500e8f26ee6ac4f4d26',
#                                 'utc_author': '2015-09-30T16:15:16',
#                                 'utc_commit': '2015-09-30T16:15:16',
#                                 'uuid': 'a92c40925731d8951418e27630f0f5a361d8e33f'},
#                     '_type': 'items',
#                     'sort': [1443636916000]},
#                    {'_id': '21a3aa5befc41fff5f7d2b7131e58ac0e2a58b33',
#                     '_index': 'git',
#                     '_score': None,
#                     '_source': {'Author': 'Alvaro del Castillo '
#                                           '<acs@bitergia.com>',
#                                 'Committer': 'Alvaro del Castillo '
#                                              '<acs@bitergia.com>',
#                                 'author_date': '2015-09-30T18:16:08',
#                                 'author_domain': 'bitergia.com',
#                                 'author_name': 'Alvaro del Castillo',
#                                 'commit_date': '2015-09-30T18:16:08',
#                                 'committer_domain': 'bitergia.com',
#                                 'committer_name': 'Alvaro del Castillo',
#                                 'files': 1,
#                                 'github_repo': 'grimoirelab/GrimoireELK',
#                                 'grimoire_creation_date': '2015-09-30T18:16:08+02:00',
#                                 'hash': '85c41a947f9882e4c3854578a4a2dddfaf701471',
#                                 'hash_short': '85c41a',
#                                 'is_git_commit': 1,
#                                 'lines_added': 13,
#                                 'lines_changed': 13,
#                                 'lines_removed': 0,
#                                 'message': 'Basic platform for ELK with '
#                                            'docker.',
#                                 'message_analyzed': 'Basic platform for ELK '
#                                                     'with docker.',
#                                 'metadata__enriched_on': '2018-03-02T20:13:38.538498',
#                                 'metadata__gelk_backend_name': 'GitEnrich',
#                                 'metadata__gelk_version': '0.30.23',
#                                 'metadata__timestamp': '2018-03-02T14:43:33.948329+00:00',
#                                 'metadata__updated_on': '2015-09-30T16:16:08+00:00',
#                                 'offset': None,
#                                 'origin': 'https://github.com/grimoirelab/GrimoireELK.git',
#                                 'repo_name': 'https://github.com/grimoirelab/GrimoireELK.git',
#                                 'tag': 'https://github.com/grimoirelab/GrimoireELK.git',
#                                 'title': 'Basic platform for ELK with docker.',
#                                 'tz': 2,
#                                 'url_id': 'grimoirelab/GrimoireELK/commit/85c41a947f9882e4c3854578a4a2dddfaf701471',
#                                 'utc_author': '2015-09-30T16:16:08',
#                                 'utc_commit': '2015-09-30T16:16:08',
#                                 'uuid': '21a3aa5befc41fff5f7d2b7131e58ac0e2a58b33'},
#                     '_type': 'items',
#                     'sort': [1443636968000]}],
#           'max_score': None,
#           'total': 2827},
#  'timed_out': False,
#  'took': 169}

# %%
authors = pd.DataFrame.from_records(buckets)

# %%
authors.head()
# Out:
#                        author        first_commit
# 0         Alvaro del Castillo 2015-09-30 18:15:16
# 1             Santiago Dueñas 2015-08-18 18:08:27
# 2           Valerio Cosentino 2017-09-14 12:14:04
# 3              Alberto Martín 2016-02-09 15:56:45
# 4  Jesus M. Gonzalez-Barahona 2015-12-31 19:16:25

# %%
authors.sort_values(by='first_commit', ascending=False, inplace=True)

# %%
pprint(authors)
# Out:
#                             author        first_commit
# 14          Miguel Ángel Fernández 2018-02-12 12:56:11
# 21                  Israel Herraiz 2018-01-09 15:40:57
# 24                           david 2017-12-07 18:54:53
# 18      Alberto Pérez García-Plaza 2017-11-24 13:05:47
# 20                     David Esler 2017-10-17 22:46:36
# 17                         valerio 2017-10-10 16:27:29
# 2                Valerio Cosentino 2017-09-14 12:14:04
# 11               valerio cosentino 2017-09-07 14:46:30
# 19                  Ali Ghassabian 2017-08-04 12:03:03
# 13                Daniel Izquierdo 2017-07-05 18:45:38
# 23                   Stephan Barth 2017-01-09 16:52:56
# 9                        alpgarcia 2016-11-17 16:59:44
# 12            David Pose Fernández 2016-11-03 15:40:38
# 8                            dpose 2016-07-07 11:53:40
# 10                 Luis Canas-Diaz 2016-07-06 10:38:13
# 15                       Quan Zhou 2016-07-04 15:37:37
# 7                             quan 2016-04-01 12:16:29
# 16                        camillem 2016-03-28 11:08:04
# 5                  Luis Cañas Díaz 2016-03-10 17:38:07
# 6                  Luis Cañas-Díaz 2016-03-10 17:36:30
# 22  J. Manrique Lopez de la Fuente 2016-03-05 08:04:02
# 3                   Alberto Martín 2016-02-09 15:56:45
# 4       Jesus M. Gonzalez-Barahona 2015-12-31 19:16:25
# 0              Alvaro del Castillo 2015-09-30 18:15:16
# 1                  Santiago Dueñas 2015-08-18 18:08:27

# %%
authors.head()
# Out:
#                         author        first_commit
# 14      Miguel Ángel Fernández 2018-02-12 12:56:11
# 21              Israel Herraiz 2018-01-09 15:40:57
# 24                       david 2017-12-07 18:54:53
# 18  Alberto Pérez García-Plaza 2017-11-24 13:05:47
# 20                 David Esler 2017-10-17 22:46:36

# %%
# number of new authors per month
by_month = authors['first_commit'].groupby([authors.first_commit.dt.year, authors.first_commit.dt.month]).agg('count')

# %%
by_month.head()
# Out:
# first_commit  first_commit
# 2015          8               1
#               9               1
#               12              1
# 2016          2               1
#               3               4
# Name: first_commit, dtype: int64

# %%
pprint(by_month)
# Out:
# first_commit  first_commit
# 2015          8               1
#               9               1
#               12              1
# 2016          2               1
#               3               4
#               4               1
#               7               3
#               11              2
# 2017          1               1
#               7               1
#               8               1
#               9               2
#               10              2
#               11              1
#               12              1
# 2018          1               1
#               2               1
# Name: first_commit, dtype: int64

# %%
by_month
# Out:
# first_commit  first_commit
# 2015          8               1
#               9               1
#               12              1
# 2016          2               1
#               3               4
#               4               1
#               7               3
#               11              2
# 2017          1               1
#               7               1
#               8               1
#               9               2
#               10              2
#               11              1
#               12              1
# 2018          1               1
#               2               1
# Name: first_commit, dtype: int64
