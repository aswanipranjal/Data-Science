# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.linear_model import Perceptron

iris = load_iris()
X = iris.data[:, (2, 3)]
y = (iris.target == 0).astype(np.int)

per_clf = Perceptron(random_state=42)
per_clf.fit(X, y)

y_pred = per_clf.predict([[2, 0.5]])

# %%
# Tensorflow API DNN
if False:
    import tensorflow as tf
    feature_columns = tf.contrib.learn.infer_real_valued_columns_from_input(X_train)
    dnn_clf = tf.contrib.learn.DNNClassifier(hidden_units=[300, 100], n_classes=10, feature_columns=feature_columns)
    dnn_clf.fit(x=X_train, y=y_train, batch_size=50, steps=40000)

# %%
# Deep Neural Network using plain tensorflow
import tensorflow as tf

n_inputs = 28*28
n_hidden1 = 300
n_hidden2 = 100
n_outputs = 10

# %%
X = tf.placeholder(tf.float32, shape=(None, n_inputs), name='X')
y = tf.placeholder(tf.float32, shape=(None), name='y')

# %%
def neuron_layer(X, n_neurons, name, activation=None):
    with tf.name_scope(name):
        n_inputs = int(X.get_shape()[1])
        stddev = 2 / np.sqrt(n_inputs)
        init = tf.truncated_normal((n_inputs, n_neurons), stddev=stddev)
        W = tf.Variable(init, name='weights')
        b = tf.Variable(tf.zeros([n_neurons]), name='biases')
        z = tf.matmul(X, W) + b
        if activation == 'relu':
            return tf.nn.relu(z)
        else:
            return z

# %%
with tf.name_scope('dnn'):
    hidden1 = neuron_layer(X, n_hidden1, 'hidden1', activation='relu')
    hidden2 = neuron_layer(hidden1, n_hidden2, 'hidden2', activation='relu')
    logits = neuron_layer(hidden2, n_outputs, 'outputs')

# %%
from tensorflow.contrib.layers import fully_connected

with tf.name_scope('dnn'):
    hidden1 = fully_connected(X, n_hidden1, scope='hidden1')
    hidden2 = fully_connected(hidden1, n_hidden2, scope='hidden2')
    logits = fully_connected(hidden2, n_outputs, scope='outputs', activation_fn=None)

# %%
with tf.name_scope('loss'):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=tf.cast(y, tf.int64), logits=logits)
    loss = tf.reduce_mean(xentropy, name='loss')

# %%
learning_rate = 0.01
with tf.name_scope('train'):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)

# %%
with tf.name_scope('eval'):
    correct = tf.nn.in_top_k(logits, tf.cast(y, tf.int64), 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

# %%
init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('C:/Users/Aman Deep Singh/Documents/Python/Data/MNIST/data/')
# Out:
# Extracting C:/Users/Aman Deep Singh/Documents/Python/Data/MNIST/data/train-images-idx3-ubyte.gz
# Extracting C:/Users/Aman Deep Singh/Documents/Python/Data/MNIST/data/train-labels-idx1-ubyte.gz
# Extracting C:/Users/Aman Deep Singh/Documents/Python/Data/MNIST/data/t10k-images-idx3-ubyte.gz
# Extracting C:/Users/Aman Deep Singh/Documents/Python/Data/MNIST/data/t10k-labels-idx1-ubyte.gz

# %%
n_epochs = 400
batch_size = 50

# %%
with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        for iteration in range(mnist.train.num_examples // batch_size):
            X_batch, y_batch = mnist.train.next_batch(batch_size)
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_train = accuracy.eval(feed_dict={X: mnist.train.images, y: mnist.train.labels})
        acc_test = accuracy.eval(feed_dict={X: mnist.test.images, y: mnist.test.labels})
        print(epoch, 'Train accuracy: ', acc_train, 'Test accuracy: ', acc_test)
    save_path = saver.save(sess, 'mnist_ckpt.ckpt')
# Out:
# 0 Train accuracy:  0.898218 Test accuracy:  0.904
# 1 Train accuracy:  0.9174 Test accuracy:  0.9214
# 2 Train accuracy:  0.929164 Test accuracy:  0.9311
# 3 Train accuracy:  0.935473 Test accuracy:  0.9363
# 4 Train accuracy:  0.942418 Test accuracy:  0.941
# 5 Train accuracy:  0.948982 Test accuracy:  0.9473
# 6 Train accuracy:  0.953436 Test accuracy:  0.9507
# 7 Train accuracy:  0.956618 Test accuracy:  0.9529
# 8 Train accuracy:  0.960545 Test accuracy:  0.9563
# 9 Train accuracy:  0.963727 Test accuracy:  0.958
# 10 Train accuracy:  0.9652 Test accuracy:  0.9606
# 11 Train accuracy:  0.968491 Test accuracy:  0.9616
# 12 Train accuracy:  0.970745 Test accuracy:  0.9636
# 13 Train accuracy:  0.9722 Test accuracy:  0.9646
# 14 Train accuracy:  0.9732 Test accuracy:  0.9649
# 15 Train accuracy:  0.9746 Test accuracy:  0.966
# 16 Train accuracy:  0.977109 Test accuracy:  0.9676
# 17 Train accuracy:  0.978018 Test accuracy:  0.9691
# 18 Train accuracy:  0.9796 Test accuracy:  0.9711
# 19 Train accuracy:  0.979964 Test accuracy:  0.9713
# 20 Train accuracy:  0.981964 Test accuracy:  0.9711
# 21 Train accuracy:  0.982873 Test accuracy:  0.9723
# 22 Train accuracy:  0.983545 Test accuracy:  0.9726
# 23 Train accuracy:  0.984255 Test accuracy:  0.9737
# 24 Train accuracy:  0.985527 Test accuracy:  0.974
# 25 Train accuracy:  0.9856 Test accuracy:  0.9731
# 26 Train accuracy:  0.986618 Test accuracy:  0.9745
# 27 Train accuracy:  0.987345 Test accuracy:  0.9744
# 28 Train accuracy:  0.987564 Test accuracy:  0.9755
# 29 Train accuracy:  0.988182 Test accuracy:  0.9753
# 30 Train accuracy:  0.989164 Test accuracy:  0.9752
# 31 Train accuracy:  0.989873 Test accuracy:  0.9761
# 32 Train accuracy:  0.990673 Test accuracy:  0.9758
# 33 Train accuracy:  0.990836 Test accuracy:  0.9769
# 34 Train accuracy:  0.991491 Test accuracy:  0.9772
# 35 Train accuracy:  0.991655 Test accuracy:  0.9777
# 36 Train accuracy:  0.992273 Test accuracy:  0.9772
# 37 Train accuracy:  0.992491 Test accuracy:  0.9766
# 38 Train accuracy:  0.992818 Test accuracy:  0.9777
# 39 Train accuracy:  0.9932 Test accuracy:  0.9784
# 40 Train accuracy:  0.993836 Test accuracy:  0.9783
# 41 Train accuracy:  0.9942 Test accuracy:  0.9783
# 42 Train accuracy:  0.994182 Test accuracy:  0.9787
# 43 Train accuracy:  0.994382 Test accuracy:  0.9786
# 44 Train accuracy:  0.995073 Test accuracy:  0.9779
# 45 Train accuracy:  0.995182 Test accuracy:  0.9788
# 46 Train accuracy:  0.995764 Test accuracy:  0.9788
# 47 Train accuracy:  0.995782 Test accuracy:  0.9786
# 48 Train accuracy:  0.996218 Test accuracy:  0.9798
# 49 Train accuracy:  0.996564 Test accuracy:  0.979
# 50 Train accuracy:  0.996745 Test accuracy:  0.9795
# 51 Train accuracy:  0.996982 Test accuracy:  0.9793
# 52 Train accuracy:  0.996982 Test accuracy:  0.9796
# 53 Train accuracy:  0.997291 Test accuracy:  0.9796
# 54 Train accuracy:  0.997255 Test accuracy:  0.9791
# 55 Train accuracy:  0.9976 Test accuracy:  0.9795
# 56 Train accuracy:  0.997764 Test accuracy:  0.9798
# 57 Train accuracy:  0.998073 Test accuracy:  0.9797
# 58 Train accuracy:  0.998127 Test accuracy:  0.9793
# 59 Train accuracy:  0.998291 Test accuracy:  0.9795
# 60 Train accuracy:  0.998255 Test accuracy:  0.9796
# 61 Train accuracy:  0.998545 Test accuracy:  0.9796
# 62 Train accuracy:  0.998382 Test accuracy:  0.98
# 63 Train accuracy:  0.998764 Test accuracy:  0.9796
# 64 Train accuracy:  0.998764 Test accuracy:  0.9806
# 65 Train accuracy:  0.998764 Test accuracy:  0.9795
# 66 Train accuracy:  0.998873 Test accuracy:  0.9798
# 67 Train accuracy:  0.999091 Test accuracy:  0.9803
# 68 Train accuracy:  0.999036 Test accuracy:  0.9799
# 69 Train accuracy:  0.999036 Test accuracy:  0.9802
# 70 Train accuracy:  0.999182 Test accuracy:  0.9799
# 71 Train accuracy:  0.999091 Test accuracy:  0.9794
# 72 Train accuracy:  0.999127 Test accuracy:  0.9807
# 73 Train accuracy:  0.999273 Test accuracy:  0.9799
# 74 Train accuracy:  0.999309 Test accuracy:  0.9799
# 75 Train accuracy:  0.9994 Test accuracy:  0.9796
# 76 Train accuracy:  0.9994 Test accuracy:  0.9801
# 77 Train accuracy:  0.9994 Test accuracy:  0.9802
# 78 Train accuracy:  0.999473 Test accuracy:  0.9802
# 79 Train accuracy:  0.999564 Test accuracy:  0.9802
# 80 Train accuracy:  0.999527 Test accuracy:  0.9805
# 81 Train accuracy:  0.9996 Test accuracy:  0.9803
# 82 Train accuracy:  0.999564 Test accuracy:  0.98
# 83 Train accuracy:  0.9996 Test accuracy:  0.9802
# 84 Train accuracy:  0.999636 Test accuracy:  0.9801
# 85 Train accuracy:  0.999691 Test accuracy:  0.9801
# 86 Train accuracy:  0.999655 Test accuracy:  0.98
# 87 Train accuracy:  0.999709 Test accuracy:  0.9803
# 88 Train accuracy:  0.999673 Test accuracy:  0.9806
# 89 Train accuracy:  0.999709 Test accuracy:  0.98
# 90 Train accuracy:  0.999745 Test accuracy:  0.9802
# 91 Train accuracy:  0.999782 Test accuracy:  0.9805
# 92 Train accuracy:  0.9998 Test accuracy:  0.9805
# 93 Train accuracy:  0.999782 Test accuracy:  0.9802
# 94 Train accuracy:  0.999836 Test accuracy:  0.9805
# 95 Train accuracy:  0.999509 Test accuracy:  0.9797
# 96 Train accuracy:  0.999891 Test accuracy:  0.9807
# 97 Train accuracy:  0.999818 Test accuracy:  0.981
# 98 Train accuracy:  0.999855 Test accuracy:  0.9808
# 99 Train accuracy:  0.999891 Test accuracy:  0.9807
# 100 Train accuracy:  0.999891 Test accuracy:  0.9802
# 101 Train accuracy:  0.999855 Test accuracy:  0.9808
# 102 Train accuracy:  0.999927 Test accuracy:  0.9807
# 103 Train accuracy:  0.999873 Test accuracy:  0.9807
# 104 Train accuracy:  0.999909 Test accuracy:  0.9808
# 105 Train accuracy:  0.999909 Test accuracy:  0.98
# 106 Train accuracy:  0.999909 Test accuracy:  0.9806
# 107 Train accuracy:  0.999909 Test accuracy:  0.9807
# 108 Train accuracy:  0.999927 Test accuracy:  0.9812
# 109 Train accuracy:  0.999909 Test accuracy:  0.981
# 110 Train accuracy:  0.999909 Test accuracy:  0.9803
# 111 Train accuracy:  0.999909 Test accuracy:  0.9808
# 112 Train accuracy:  0.999927 Test accuracy:  0.9803
# 113 Train accuracy:  0.999927 Test accuracy:  0.9807
# 114 Train accuracy:  0.999927 Test accuracy:  0.9807
# 115 Train accuracy:  0.999945 Test accuracy:  0.9809
# 116 Train accuracy:  0.999927 Test accuracy:  0.9805
# 117 Train accuracy:  0.999945 Test accuracy:  0.9811
# 118 Train accuracy:  0.999927 Test accuracy:  0.9803
# 119 Train accuracy:  0.999964 Test accuracy:  0.9806
# 120 Train accuracy:  0.999945 Test accuracy:  0.9808
# 121 Train accuracy:  0.999945 Test accuracy:  0.9812
# 122 Train accuracy:  0.999945 Test accuracy:  0.9808
# 123 Train accuracy:  0.999927 Test accuracy:  0.9805
# 124 Train accuracy:  0.999964 Test accuracy:  0.9808
# 125 Train accuracy:  0.999945 Test accuracy:  0.981
# 126 Train accuracy:  0.999964 Test accuracy:  0.9809
# 127 Train accuracy:  0.999945 Test accuracy:  0.9809
# 128 Train accuracy:  0.999964 Test accuracy:  0.9811
# 129 Train accuracy:  0.999964 Test accuracy:  0.9808
# 130 Train accuracy:  0.999964 Test accuracy:  0.9813
# 131 Train accuracy:  0.999964 Test accuracy:  0.981
# 132 Train accuracy:  0.999964 Test accuracy:  0.981
# 133 Train accuracy:  0.999964 Test accuracy:  0.981
# 134 Train accuracy:  0.999964 Test accuracy:  0.9808
# 135 Train accuracy:  0.999964 Test accuracy:  0.9808
# 136 Train accuracy:  0.999964 Test accuracy:  0.9811
# 137 Train accuracy:  0.999964 Test accuracy:  0.9807
# 138 Train accuracy:  0.999982 Test accuracy:  0.9808
# 139 Train accuracy:  0.999964 Test accuracy:  0.9807
# 140 Train accuracy:  0.999982 Test accuracy:  0.981
# 141 Train accuracy:  0.999964 Test accuracy:  0.9808
# 142 Train accuracy:  0.999982 Test accuracy:  0.9809
# 143 Train accuracy:  0.999982 Test accuracy:  0.9808
# 144 Train accuracy:  0.999982 Test accuracy:  0.9807
# 145 Train accuracy:  0.999982 Test accuracy:  0.9811
# 146 Train accuracy:  0.999982 Test accuracy:  0.9811
# 147 Train accuracy:  0.999982 Test accuracy:  0.9811
# 148 Train accuracy:  0.999982 Test accuracy:  0.9811
# 149 Train accuracy:  0.999982 Test accuracy:  0.9808
# 150 Train accuracy:  0.999982 Test accuracy:  0.981
# 151 Train accuracy:  0.999982 Test accuracy:  0.9808
# 152 Train accuracy:  0.999982 Test accuracy:  0.9811
# 153 Train accuracy:  1.0 Test accuracy:  0.9808
# 154 Train accuracy:  0.999982 Test accuracy:  0.9808
# 155 Train accuracy:  0.999982 Test accuracy:  0.981
# 156 Train accuracy:  1.0 Test accuracy:  0.9809
# 157 Train accuracy:  0.999982 Test accuracy:  0.9812
# 158 Train accuracy:  0.999982 Test accuracy:  0.9812
# 159 Train accuracy:  0.999982 Test accuracy:  0.9808
# 160 Train accuracy:  0.999982 Test accuracy:  0.9808
# 161 Train accuracy:  0.999982 Test accuracy:  0.9808
# 162 Train accuracy:  1.0 Test accuracy:  0.9808
# 163 Train accuracy:  0.999982 Test accuracy:  0.9807
# 164 Train accuracy:  0.999982 Test accuracy:  0.9808
# 165 Train accuracy:  0.999982 Test accuracy:  0.9809
# 166 Train accuracy:  1.0 Test accuracy:  0.9812
# 167 Train accuracy:  1.0 Test accuracy:  0.9809
# 168 Train accuracy:  1.0 Test accuracy:  0.9811
# 169 Train accuracy:  1.0 Test accuracy:  0.9811
# 170 Train accuracy:  1.0 Test accuracy:  0.981
# 171 Train accuracy:  0.999982 Test accuracy:  0.9809
# 172 Train accuracy:  0.999982 Test accuracy:  0.9808
# 173 Train accuracy:  1.0 Test accuracy:  0.981
# 174 Train accuracy:  1.0 Test accuracy:  0.9811
# 175 Train accuracy:  1.0 Test accuracy:  0.9813
# 176 Train accuracy:  1.0 Test accuracy:  0.9808
# 177 Train accuracy:  1.0 Test accuracy:  0.9811
# 178 Train accuracy:  1.0 Test accuracy:  0.9809
# 179 Train accuracy:  1.0 Test accuracy:  0.9809
# 180 Train accuracy:  1.0 Test accuracy:  0.9809
# 181 Train accuracy:  1.0 Test accuracy:  0.9811
# 182 Train accuracy:  1.0 Test accuracy:  0.9808
# 183 Train accuracy:  0.999982 Test accuracy:  0.981
# 184 Train accuracy:  1.0 Test accuracy:  0.9812
# 185 Train accuracy:  1.0 Test accuracy:  0.9816
# 186 Train accuracy:  1.0 Test accuracy:  0.9811
# 187 Train accuracy:  1.0 Test accuracy:  0.9811
# 188 Train accuracy:  1.0 Test accuracy:  0.9814
# 189 Train accuracy:  1.0 Test accuracy:  0.9813
# 190 Train accuracy:  1.0 Test accuracy:  0.9811
# 191 Train accuracy:  1.0 Test accuracy:  0.9811
# 192 Train accuracy:  1.0 Test accuracy:  0.9812
# 193 Train accuracy:  1.0 Test accuracy:  0.9813
# 194 Train accuracy:  1.0 Test accuracy:  0.9812
# 195 Train accuracy:  1.0 Test accuracy:  0.9812
# 196 Train accuracy:  1.0 Test accuracy:  0.9812
# 197 Train accuracy:  1.0 Test accuracy:  0.981
# 198 Train accuracy:  1.0 Test accuracy:  0.9813
# 199 Train accuracy:  1.0 Test accuracy:  0.9812
# 200 Train accuracy:  1.0 Test accuracy:  0.9815
# 201 Train accuracy:  1.0 Test accuracy:  0.9813
# 202 Train accuracy:  1.0 Test accuracy:  0.9812
# 203 Train accuracy:  1.0 Test accuracy:  0.9813
# 204 Train accuracy:  1.0 Test accuracy:  0.9811
# 205 Train accuracy:  1.0 Test accuracy:  0.9813
# 206 Train accuracy:  1.0 Test accuracy:  0.9813
# 207 Train accuracy:  1.0 Test accuracy:  0.9813
# 208 Train accuracy:  1.0 Test accuracy:  0.9814
# 209 Train accuracy:  1.0 Test accuracy:  0.9815
# 210 Train accuracy:  1.0 Test accuracy:  0.9815
# 211 Train accuracy:  1.0 Test accuracy:  0.9813
# 212 Train accuracy:  1.0 Test accuracy:  0.9814
# 213 Train accuracy:  1.0 Test accuracy:  0.9812
# 214 Train accuracy:  1.0 Test accuracy:  0.9811
# 215 Train accuracy:  1.0 Test accuracy:  0.9815
# 216 Train accuracy:  1.0 Test accuracy:  0.9812
# 217 Train accuracy:  1.0 Test accuracy:  0.9811
# 218 Train accuracy:  1.0 Test accuracy:  0.9815
# 219 Train accuracy:  1.0 Test accuracy:  0.9813
# 220 Train accuracy:  1.0 Test accuracy:  0.9813
# 221 Train accuracy:  1.0 Test accuracy:  0.9813
# 222 Train accuracy:  1.0 Test accuracy:  0.9813
# 223 Train accuracy:  1.0 Test accuracy:  0.9813
# 224 Train accuracy:  1.0 Test accuracy:  0.9814
# 225 Train accuracy:  1.0 Test accuracy:  0.9813
# 226 Train accuracy:  1.0 Test accuracy:  0.9811
# 227 Train accuracy:  1.0 Test accuracy:  0.9814
# 228 Train accuracy:  1.0 Test accuracy:  0.9813
# 229 Train accuracy:  1.0 Test accuracy:  0.9814
# 230 Train accuracy:  1.0 Test accuracy:  0.9816
# 231 Train accuracy:  1.0 Test accuracy:  0.9812
# 232 Train accuracy:  1.0 Test accuracy:  0.9812
# 233 Train accuracy:  1.0 Test accuracy:  0.9815
# 234 Train accuracy:  1.0 Test accuracy:  0.9813
# 235 Train accuracy:  1.0 Test accuracy:  0.9812
# 236 Train accuracy:  1.0 Test accuracy:  0.9814
# 237 Train accuracy:  1.0 Test accuracy:  0.9813
# 238 Train accuracy:  1.0 Test accuracy:  0.9814
# 239 Train accuracy:  1.0 Test accuracy:  0.9815
# 240 Train accuracy:  1.0 Test accuracy:  0.9814
# 241 Train accuracy:  1.0 Test accuracy:  0.9814
# 242 Train accuracy:  1.0 Test accuracy:  0.9814
# 243 Train accuracy:  1.0 Test accuracy:  0.9813
# 244 Train accuracy:  1.0 Test accuracy:  0.9813
# 245 Train accuracy:  1.0 Test accuracy:  0.9815
# 246 Train accuracy:  1.0 Test accuracy:  0.9813
# 247 Train accuracy:  1.0 Test accuracy:  0.9812
# 248 Train accuracy:  1.0 Test accuracy:  0.9815
# 249 Train accuracy:  1.0 Test accuracy:  0.9814
# 250 Train accuracy:  1.0 Test accuracy:  0.9813
# 251 Train accuracy:  1.0 Test accuracy:  0.9814
# 252 Train accuracy:  1.0 Test accuracy:  0.9814
# 253 Train accuracy:  1.0 Test accuracy:  0.9813
# 254 Train accuracy:  1.0 Test accuracy:  0.9812
# 255 Train accuracy:  1.0 Test accuracy:  0.9811
# 256 Train accuracy:  1.0 Test accuracy:  0.9812
# 257 Train accuracy:  1.0 Test accuracy:  0.981
# 258 Train accuracy:  1.0 Test accuracy:  0.9814
# 259 Train accuracy:  1.0 Test accuracy:  0.9814
# 260 Train accuracy:  1.0 Test accuracy:  0.9813
# 261 Train accuracy:  1.0 Test accuracy:  0.9811
# 262 Train accuracy:  1.0 Test accuracy:  0.9812
# 263 Train accuracy:  1.0 Test accuracy:  0.9812
# 264 Train accuracy:  1.0 Test accuracy:  0.9814
# 265 Train accuracy:  1.0 Test accuracy:  0.9811
# 266 Train accuracy:  1.0 Test accuracy:  0.9813
# 267 Train accuracy:  1.0 Test accuracy:  0.9813
# 268 Train accuracy:  1.0 Test accuracy:  0.9813
# 269 Train accuracy:  1.0 Test accuracy:  0.9815
# 270 Train accuracy:  1.0 Test accuracy:  0.9813
# 271 Train accuracy:  1.0 Test accuracy:  0.9814
# 272 Train accuracy:  1.0 Test accuracy:  0.9812
# 273 Train accuracy:  1.0 Test accuracy:  0.9814
# 274 Train accuracy:  1.0 Test accuracy:  0.9814
# 275 Train accuracy:  1.0 Test accuracy:  0.9813
# 276 Train accuracy:  1.0 Test accuracy:  0.9813
# 277 Train accuracy:  1.0 Test accuracy:  0.9813
# 278 Train accuracy:  1.0 Test accuracy:  0.9814
# 279 Train accuracy:  1.0 Test accuracy:  0.9812
# 280 Train accuracy:  1.0 Test accuracy:  0.9814
# 281 Train accuracy:  1.0 Test accuracy:  0.9814
# 282 Train accuracy:  1.0 Test accuracy:  0.9812
# 283 Train accuracy:  1.0 Test accuracy:  0.9812
# 284 Train accuracy:  1.0 Test accuracy:  0.9813
# 285 Train accuracy:  1.0 Test accuracy:  0.9813
# 286 Train accuracy:  1.0 Test accuracy:  0.9814
# 287 Train accuracy:  1.0 Test accuracy:  0.9811
# 288 Train accuracy:  1.0 Test accuracy:  0.9814
# 289 Train accuracy:  1.0 Test accuracy:  0.9814
# 290 Train accuracy:  1.0 Test accuracy:  0.9814
# 291 Train accuracy:  1.0 Test accuracy:  0.9814
# 292 Train accuracy:  1.0 Test accuracy:  0.9814
# 293 Train accuracy:  1.0 Test accuracy:  0.9813
# 294 Train accuracy:  1.0 Test accuracy:  0.9813
# 295 Train accuracy:  1.0 Test accuracy:  0.9813
# 296 Train accuracy:  1.0 Test accuracy:  0.9813
# 297 Train accuracy:  1.0 Test accuracy:  0.9815
# 298 Train accuracy:  1.0 Test accuracy:  0.9811
# 299 Train accuracy:  1.0 Test accuracy:  0.9812
# 300 Train accuracy:  1.0 Test accuracy:  0.9814
# 301 Train accuracy:  1.0 Test accuracy:  0.9814
# 302 Train accuracy:  1.0 Test accuracy:  0.9813
# 303 Train accuracy:  1.0 Test accuracy:  0.9812
# 304 Train accuracy:  1.0 Test accuracy:  0.9813
# 305 Train accuracy:  1.0 Test accuracy:  0.9813
# 306 Train accuracy:  1.0 Test accuracy:  0.9813
# 307 Train accuracy:  1.0 Test accuracy:  0.9815
# 308 Train accuracy:  1.0 Test accuracy:  0.9815
# 309 Train accuracy:  1.0 Test accuracy:  0.9814
# 310 Train accuracy:  1.0 Test accuracy:  0.9813
# 311 Train accuracy:  1.0 Test accuracy:  0.9813
# 312 Train accuracy:  1.0 Test accuracy:  0.9813
# 313 Train accuracy:  1.0 Test accuracy:  0.9814
# 314 Train accuracy:  1.0 Test accuracy:  0.9814
# 315 Train accuracy:  1.0 Test accuracy:  0.9813
# 316 Train accuracy:  1.0 Test accuracy:  0.9816
# 317 Train accuracy:  1.0 Test accuracy:  0.9812
# 318 Train accuracy:  1.0 Test accuracy:  0.9813
# 319 Train accuracy:  1.0 Test accuracy:  0.9813
# 320 Train accuracy:  1.0 Test accuracy:  0.9812
# 321 Train accuracy:  1.0 Test accuracy:  0.9811
# 322 Train accuracy:  1.0 Test accuracy:  0.9814
# 323 Train accuracy:  1.0 Test accuracy:  0.9813
# 324 Train accuracy:  1.0 Test accuracy:  0.9813
# 325 Train accuracy:  1.0 Test accuracy:  0.9813
# 326 Train accuracy:  1.0 Test accuracy:  0.9812
# 327 Train accuracy:  1.0 Test accuracy:  0.9815
# 328 Train accuracy:  1.0 Test accuracy:  0.9815
# 329 Train accuracy:  1.0 Test accuracy:  0.9812
# 330 Train accuracy:  1.0 Test accuracy:  0.9815
# 331 Train accuracy:  1.0 Test accuracy:  0.9814
# 332 Train accuracy:  1.0 Test accuracy:  0.9815
# 333 Train accuracy:  1.0 Test accuracy:  0.9812
# 334 Train accuracy:  1.0 Test accuracy:  0.9815
# 335 Train accuracy:  1.0 Test accuracy:  0.9814
# 336 Train accuracy:  1.0 Test accuracy:  0.9814
# 337 Train accuracy:  1.0 Test accuracy:  0.9813
# 338 Train accuracy:  1.0 Test accuracy:  0.9812
# 339 Train accuracy:  1.0 Test accuracy:  0.9813
# 340 Train accuracy:  1.0 Test accuracy:  0.9816
# 341 Train accuracy:  1.0 Test accuracy:  0.9813
# 342 Train accuracy:  1.0 Test accuracy:  0.9814
# 343 Train accuracy:  1.0 Test accuracy:  0.9813
# 344 Train accuracy:  1.0 Test accuracy:  0.9813
# 345 Train accuracy:  1.0 Test accuracy:  0.9811
# 346 Train accuracy:  1.0 Test accuracy:  0.9813
# 347 Train accuracy:  1.0 Test accuracy:  0.9812
# 348 Train accuracy:  1.0 Test accuracy:  0.9813
# 349 Train accuracy:  1.0 Test accuracy:  0.9811
# 350 Train accuracy:  1.0 Test accuracy:  0.9812
# 351 Train accuracy:  1.0 Test accuracy:  0.9814
# 352 Train accuracy:  1.0 Test accuracy:  0.9814
# 353 Train accuracy:  1.0 Test accuracy:  0.9813
# 354 Train accuracy:  1.0 Test accuracy:  0.9813
# 355 Train accuracy:  1.0 Test accuracy:  0.9812
# 356 Train accuracy:  1.0 Test accuracy:  0.9813
# 357 Train accuracy:  1.0 Test accuracy:  0.9816
# 358 Train accuracy:  1.0 Test accuracy:  0.9815
# 359 Train accuracy:  1.0 Test accuracy:  0.9814
# 360 Train accuracy:  1.0 Test accuracy:  0.9813
# 361 Train accuracy:  1.0 Test accuracy:  0.9814
# 362 Train accuracy:  1.0 Test accuracy:  0.9812
# 363 Train accuracy:  1.0 Test accuracy:  0.9812
# 364 Train accuracy:  1.0 Test accuracy:  0.9814
# 365 Train accuracy:  1.0 Test accuracy:  0.9812
# 366 Train accuracy:  1.0 Test accuracy:  0.9814
# 367 Train accuracy:  1.0 Test accuracy:  0.9812
# 368 Train accuracy:  1.0 Test accuracy:  0.9812
# 369 Train accuracy:  1.0 Test accuracy:  0.9814
# 370 Train accuracy:  1.0 Test accuracy:  0.9814
# 371 Train accuracy:  1.0 Test accuracy:  0.9813
# 372 Train accuracy:  1.0 Test accuracy:  0.9814
# 373 Train accuracy:  1.0 Test accuracy:  0.9813
# 374 Train accuracy:  1.0 Test accuracy:  0.9813
# 375 Train accuracy:  1.0 Test accuracy:  0.9812
# 376 Train accuracy:  1.0 Test accuracy:  0.9813
# 377 Train accuracy:  1.0 Test accuracy:  0.9813
# 378 Train accuracy:  1.0 Test accuracy:  0.9813
# 379 Train accuracy:  1.0 Test accuracy:  0.9812
# 380 Train accuracy:  1.0 Test accuracy:  0.9815
# 381 Train accuracy:  1.0 Test accuracy:  0.9815
# 382 Train accuracy:  1.0 Test accuracy:  0.9814
# 383 Train accuracy:  1.0 Test accuracy:  0.9813
# 384 Train accuracy:  1.0 Test accuracy:  0.9814
# 385 Train accuracy:  1.0 Test accuracy:  0.9814
# 386 Train accuracy:  1.0 Test accuracy:  0.9813
# 387 Train accuracy:  1.0 Test accuracy:  0.9816
# 388 Train accuracy:  1.0 Test accuracy:  0.9814
# 389 Train accuracy:  1.0 Test accuracy:  0.9815
# 390 Train accuracy:  1.0 Test accuracy:  0.9811
# 391 Train accuracy:  1.0 Test accuracy:  0.9812
# 392 Train accuracy:  1.0 Test accuracy:  0.9812
# 393 Train accuracy:  1.0 Test accuracy:  0.9815
# 394 Train accuracy:  1.0 Test accuracy:  0.9814
# 395 Train accuracy:  1.0 Test accuracy:  0.9812
# 396 Train accuracy:  1.0 Test accuracy:  0.9812
# 397 Train accuracy:  1.0 Test accuracy:  0.9814
# 398 Train accuracy:  1.0 Test accuracy:  0.9813
# 399 Train accuracy:  1.0 Test accuracy:  0.9813
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#
# C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#
# C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\tensorflow\python\framework\errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     472             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 473             c_api.TF_GetCode(self.status.status))
#     474     # Delete the underlying status object from memory otherwise it stays alive
#
# NotFoundError: Failed to create a directory: ; No such file or directory
# 	 [[Node: save/SaveV2 = SaveV2[dtypes=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save/Const_0_0, save/SaveV2/tensor_names, save/SaveV2/shape_and_slices, dnn/hidden1/biases, dnn/hidden1/weights, dnn_1/hidden1/biases, dnn_1/hidden1/weights, dnn_1/hidden2/biases, dnn_1/hidden2/weights, dnn_1/outputs/biases, dnn_1/outputs/weights, hidden1/biases, hidden1/weights, hidden2/biases, hidden2/weights, outputs/biases, outputs/weights)]]
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py in save(self, sess, save_path, global_step, latest_filename, meta_graph_suffix, write_meta_graph, write_state)
#    1572               self.saver_def.save_tensor_name,
# -> 1573               {self.saver_def.filename_tensor_name: checkpoint_file})
#    1574         else:
#
# C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#
# C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#
# C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#
# C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1335           pass
# -> 1336       raise type(e)(node_def, op, message)
#    1337
#
# NotFoundError: Failed to create a directory: ; No such file or directory
# 	 [[Node: save/SaveV2 = SaveV2[dtypes=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save/Const_0_0, save/SaveV2/tensor_names, save/SaveV2/shape_and_slices, dnn/hidden1/biases, dnn/hidden1/weights, dnn_1/hidden1/biases, dnn_1/hidden1/weights, dnn_1/hidden2/biases, dnn_1/hidden2/weights, dnn_1/outputs/biases, dnn_1/outputs/weights, hidden1/biases, hidden1/weights, hidden2/biases, hidden2/weights, outputs/biases, outputs/weights)]]
#
# Caused by op 'save/SaveV2', defined at:
#   File "C:\Users\Aman Deep Singh\Anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\Aman Deep Singh\Anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\tornado\ioloop.py", line 887, in start
#     handler_func(fd_obj, events)
#   File "C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\tornado\stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\tornado\stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2821, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-16-74f077792af3>", line 2, in <module>
#     saver = tf.train.Saver()
#   File "C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 1218, in __init__
#     self.build()
#   File "C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 1227, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 1263, in _build
#     build_save=build_save, build_restore=build_restore)
#   File "C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 748, in _build_internal
#     save_tensor = self._AddSaveOps(filename_tensor, saveables)
#   File "C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 296, in _AddSaveOps
#     save = self.save_op(filename_tensor, saveables)
#   File "C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 239, in save_op
#     tensors)
#   File "C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\tensorflow\python\ops\gen_io_ops.py", line 1162, in save_v2
#     shape_and_slices=shape_and_slices, tensors=tensors, name=name)
#   File "C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 2956, in create_op
#     op_def=op_def)
#   File "C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 1470, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# NotFoundError (see above for traceback): Failed to create a directory: ; No such file or directory
# 	 [[Node: save/SaveV2 = SaveV2[dtypes=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save/Const_0_0, save/SaveV2/tensor_names, save/SaveV2/shape_and_slices, dnn/hidden1/biases, dnn/hidden1/weights, dnn_1/hidden1/biases, dnn_1/hidden1/weights, dnn_1/hidden2/biases, dnn_1/hidden2/weights, dnn_1/outputs/biases, dnn_1/outputs/weights, hidden1/biases, hidden1/weights, hidden2/biases, hidden2/weights, outputs/biases, outputs/weights)]]
#
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-362b582bdd47> in <module>()
#       8         acc_test = accuracy.eval(feed_dict={X: mnist.test.images, y: mnist.test.labels})
#       9         print(epoch, 'Train accuracy: ', acc_train, 'Test accuracy: ', acc_test)
# ---> 10     save_path = saver.save(sess, 'mnist_ckpt.ckpt')
#
# C:\Users\Aman Deep Singh\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py in save(self, sess, save_path, global_step, latest_filename, meta_graph_suffix, write_meta_graph, write_state)
#    1592               "Parent directory of {} doesn't exist, can't save.".format(
#    1593                   save_path))
# -> 1594         raise exc
#    1595
#    1596     if write_meta_graph:
#
# ValueError: Parent directory of mnist_ckpt.ckpt doesn't exist, can't save.

# %%
# Using the neural network
if False:
    with tf.Session() as sess:
        saver.restore(sess, 'mnist_ckpt.ckpt')
        # X_new_scaled = [...]
        Z = logits.eval(feed_dict={X: X_new_scaled})
        y_pred = np.argmax(Z, axis=1)
